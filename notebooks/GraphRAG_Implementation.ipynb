# %% [markdown]
# <a href="https://colab.research.google.com/github/towardsai/ai-tutor-rag-system/blob/main/notebooks/GraphRAG_Implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Basic GraphRAG Implementation
#
# Classic RAG retrieves *chunks*; **GraphRAG** (Microsoft's open-source pipeline) first has an LLM read the corpus and build a **knowledge graph** — entities, relationships, and community summaries — then answers questions from the graph: **global** search for corpus-wide questions, **local** search for entity-centric ones. This notebook runs the whole pipeline on one research paper via the `graphrag` CLI.
#
# Two things to know before you run it (as of July 2026):
#
# - **Vendor note:** the `graphrag` package's default pipeline is OpenAI-first, so this lesson uses an OpenAI key/model directly (like the audio and caching lessons' vendor-native halves). The course toolkit isn't needed here — nothing in this lesson is a retrieval pipeline we'd build ourselves; that comparison comes at the end.
# - **Cost warning:** graph indexing makes *many* LLM calls even for one document (entity extraction, relationship extraction, community summaries). Run it on the provided single paper first and watch the meter before pointing it at anything larger.

# %%
# !pip install -q graphrag==3.1.0 ruamel.yaml==0.19.1 pypdf==6.10.2 \
                2>/dev/null # Suppress unfatal errors
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.7/91.7 kB 3.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 kB 10.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.0/50.0 kB 4.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 3.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.8/298.8 kB 10.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.1/118.1 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 336.3/336.3 kB 16.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 53.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.1/192.1 kB 9.9 MB/s eta 0:00:00
# ...

# %%
import os
import sys

IN_COLAB = "google.colab" in sys.modules

# GraphRAG reads its key from GRAPHRAG_API_KEY (we use OpenAI models here).
if IN_COLAB:
    from google.colab import userdata

    os.environ["GRAPHRAG_API_KEY"] = userdata.get("OPENAI_API_KEY")
else:
    from dotenv import load_dotenv

    load_dotenv()  # OPENAI_API_KEY from the repo-root .env
    os.environ["GRAPHRAG_API_KEY"] = os.environ["OPENAI_API_KEY"]

# %%
import io
import pathlib
import zipfile

import requests

# Input data directory (relative path — identical in Colab and locally)
pathlib.Path("./ragtest/input").mkdir(parents=True, exist_ok=True)

# The sample document — the LoRA paper — ships as a PDF inside the course
# dataset's research-papers zip. Download the zip, then extract the paper's
# text with pypdf (📎 the Section 6 parsing lesson's baseline), since
# GraphRAG wants plain-text input.
ZIP_URL = (
    "https://huggingface.co/datasets/towardsai-tutors/full-stack-ai-engineering-data"
    "/resolve/main/parsing_PDFs_research_papers.zip"
)
LORA_PDF = "research_papers_llamaparse/2106.09685v2.pdf"  # Hu et al., "LoRA" (arXiv:2106.09685)

archive = zipfile.ZipFile(io.BytesIO(requests.get(ZIP_URL, timeout=300).content))

from pypdf import PdfReader

reader = PdfReader(io.BytesIO(archive.read(LORA_PDF)))
text = "\n".join(page.extract_text() or "" for page in reader.pages)

out_path = pathlib.Path("./ragtest/input/LoRA.txt")
out_path.write_text(text, encoding="utf-8")
print(f"Wrote {out_path} — {len(text):,} characters from {len(reader.pages)} pages")
# Out:
# Wrote ragtest/input/LoRA.txt — 82,714 characters from 26 pages

# %%
import os
if not os.path.exists("./ragtest/settings.yaml"):
    # !yes "" | python -m graphrag init --root ./ragtest
else:
    print("Already initialized — skipping.")
# Out:
# Specify the default chat model to use [gpt-4.1]: Specify the default embedding model to use [text-embedding-3-large]:

# %%
import re
import yaml
from ruamel.yaml import YAML

def update_yaml_ruamel(file_path, path, new_value, create_missing=False):
    y = YAML()
    y.preserve_quotes = True
    y.width = 4096

    with open(file_path) as f:
        data = y.load(f)

    keys = path.split('.')
    current = data
    for i, key in enumerate(keys[:-1]):
        if key not in current:
            if not create_missing:
                raise KeyError(
                    f"Path '{'.'.join(keys[:i+1])}' not found. "
                    f"Available at this level: {list(current.keys())}"
                )
            current[key] = {}
        current = current[key]

    if keys[-1] not in current and not create_missing:
        raise KeyError(f"Leaf key '{keys[-1]}' not found under '{'.'.join(keys[:-1])}'")

    old = current.get(keys[-1])
    current[keys[-1]] = new_value

    with open(file_path, 'w') as f:
        y.dump(data, f)
    print(f"Updated {path}: {old} → {new_value}")

file_path = './ragtest/settings.yaml'

# A current, inexpensive model (as of July 2026): indexing makes MANY calls, so
# price matters more than peak quality here. (Reasoning-tier flagships can need
# extra settings in graphrag's config — the mini tier is the reliable default.)
update_yaml_ruamel(file_path, 'completion_models.default_completion_model.model', 'gpt-5.6-luna')
# Out:
# Updated completion_models.default_completion_model.model: gpt-4.1 → gpt-5.6-luna

# %%
# Indexing — the expensive step: the LLM reads the corpus and builds the graph
# (entities → relationships → communities → community summaries).

# !python -m graphrag index --root ./ragtest
# Out:
# 08:06:15 - LiteLLM:WARNING: common_utils.py:979 - litellm: could not pre-load bedrock-runtime response stream shape — Bedrock event-stream decoding will be unavailable. Error: No module named 'botocore'
# 08:06:15 - LiteLLM:WARNING: common_utils.py:24 - litellm: could not pre-load sagemaker-runtime response stream shape — SageMaker event-stream decoding will be unavailable. Error: No module named 'botocore'
# Starting pipeline with workflows: load_input_documents, create_base_text_units, create_final_documents, extract_graph, finalize_graph, extract_covariates, create_communities, create_final_text_units, create_community_reports, generate_text_embeddings
# Starting workflow: load_input_documents
#
# Workflow complete: load_input_documents
# Starting workflow: create_base_text_units
#   1 / 1 ............................................................................................
# Workflow complete: create_base_text_units
# Starting workflow: create_final_documents
#
# ...

# %%
# Global Search

# !python -m graphrag query \
           --root ./ragtest \
           --method global \
           "What is this text document about?"
# Out:
# 08:11:06 - LiteLLM:WARNING: common_utils.py:979 - litellm: could not pre-load bedrock-runtime response stream shape — Bedrock event-stream decoding will be unavailable. Error: No module named 'botocore'
# 08:11:07 - LiteLLM:WARNING: common_utils.py:24 - litellm: could not pre-load sagemaker-runtime response stream shape — SageMaker event-stream decoding will be unavailable. Error: No module named 'botocore'
# ## Overview
#
# The document is a collection of interconnected academic and technical research summaries in machine learning, natural-language processing, and, to a lesser extent, computer vision. Its central subject is how to adapt large pretrained Transformer language models efficiently, especially by training far fewer parameters than conventional full fine-tuning. It focuses on research communities, publications, researchers, datasets, benchmarks, conferences, and software rather than on a single organization or event. [Data: Reports (24, 9, 62, 0, 18, +more)]
#
# ...

# %%
# Local search

# !python -m graphrag query \
           --root ./ragtest \
           --method local \
           " what is Low Rank Adaptation"
# Out:
# 08:11:33 - LiteLLM:WARNING: common_utils.py:979 - litellm: could not pre-load bedrock-runtime response stream shape — Bedrock event-stream decoding will be unavailable. Error: No module named 'botocore'
# 08:11:34 - LiteLLM:WARNING: common_utils.py:24 - litellm: could not pre-load sagemaker-runtime response stream shape — SageMaker event-stream decoding will be unavailable. Error: No module named 'botocore'
# ## Low-Rank Adaptation (LoRA)
#
# Low-Rank Adaptation, or **LoRA**, is a parameter-efficient method for adapting a pretrained neural network—especially Transformer-based language models—to a new task. Instead of updating all of the model’s original weights, LoRA freezes them and adds small, trainable low-rank matrices that represent the task-specific weight update. For a pretrained weight matrix \(W_0\), LoRA uses:
#
# \[
# W = W_0 + BA
# \]
#
# ...

# %% [markdown]
# ### Important Note: You must update the file path based on your implementation as the file name <time stamp> change with each implementation. You can also visualize the Parquet file using Pandas.

# %%
import duckdb

# The graph is just Parquet files — inspect the extracted entities directly.
# (The output/ file names carry a run timestamp in some versions — adjust if needed.)

query_result = duckdb.query("SELECT * FROM './ragtest/output/entities.parquet'")
print(query_result)
# Out:
# ┌──────────────────────────────────────┬───────────────────┬──────────────────────────────────────────────────┬──────────────┬───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬────────────────────────────────────────────────────────────────────────────────────────────────────
# ...

# %%
# Filter the extracted entities by type — here, the organizations the paper mentions.
ORGANIZATION_result = duckdb.query("""
    SELECT *
    FROM './ragtest/output/entities.parquet'
    WHERE type = 'ORGANIZATION'
""")

# Print the result
print(ORGANIZATION_result)
# Out:
# ┌──────────────────────────────────────┬───────────────────┬───────────────────────────┬──────────────┬───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ...
