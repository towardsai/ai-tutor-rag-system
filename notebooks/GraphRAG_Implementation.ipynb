# %% [markdown]
# # Basic GraphRAG Implementation

# %%
# !pip install -q graphrag==2.5.0 ruamel.yaml==0.18.15 \
                2>/dev/null # Suppress unfatal errors
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 3.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.8/80.8 kB 5.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 kB 6.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.5/46.5 kB 2.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 4.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 370.4/370.4 kB 14.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.7/119.7 kB 11.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 303.2/303.2 kB 23.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.9/190.9 kB 15.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.8/298.8 kB 22.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 412.9/412.9 kB 24.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.3/79.3 kB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 75.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.8/35.8 MB 29.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 85.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 110.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 754.1/754.1 kB 43.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.8/211.8 kB 17.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 917.8/917.8 kB 50.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.6/26.6 MB 15.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 364.6/364.6 kB 24.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.3/192.3 kB 14.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.9/116.9 kB 9.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 901.7/901.7 kB 47.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.2/38.2 MB 21.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 98.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 112.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 MB 12.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.6/229.6 kB 15.3 MB/s eta 0:00:00

# %%
import os
from google.colab import userdata

# os.environ['GRAPHRAG_API_KEY'] = "GRAPHRAG_API_KEY"

os.environ['GRAPHRAG_API_KEY'] = userdata.get('OPENAI_API_KEY')

# %%
from huggingface_hub import hf_hub_download

# Input data directory
os.makedirs("/content/ragtest/input", exist_ok=True)

# Downloading text file from huggingface
hf_hub_download(repo_id="jaiganesan/research_papers", repo_type="dataset", filename="LoRA.txt",local_dir="/content/ragtest/input")
# Out:
# LoRA.txt: 0.00B [00:00, ?B/s]
# '/content/ragtest/input/LoRA.txt'

# %%
# Initializing GraphRAG Project
# Ignore the Warnings

# !python -m graphrag init --root /content/ragtest
# Out:
# 2025-09-19 08:52:10.0235 - INFO - graphrag.cli.initialize - Initializing project at /content/ragtest

# %%
import re
import yaml

def update_yaml_ruamel(file_path, path, new_value):
    """
    Update YAML using ruamel.yaml which preserves comments and formatting

    Installation: pip install ruamel.yaml
    """
    from ruamel.yaml import YAML

    yaml = YAML()
    yaml.preserve_quotes = True
    yaml.width = 4096

    with open(file_path, 'r') as file:
        data = yaml.load(file)

    # Navigate to the target location
    keys = path.split('.')
    current = data

    for key in keys[:-1]:
        if key not in current:
            current[key] = {}
        current = current[key]

    # Set the new value
    current[keys[-1]] = new_value

    # Write back to file
    with open(file_path, 'w') as file:
        yaml.dump(data, file)

    print(f"Updated {path} = {new_value}")

file_path = '/content/ragtest/settings.yaml'

update_yaml_ruamel(file_path, 'models.default_chat_model.model', 'gpt-4o') # GPT 5 Might give some error
# Out:
# Updated models.default_chat_model.model = gpt-4o

# %%
# Indexing

# !python -m graphrag index --root /content/ragtest
# Out:
# 2025-09-19 09:17:49.836344: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1758273470.172930    6960 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1758273470.259012    6960 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1758273470.951592    6960 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1758273470.951662    6960 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1758273470.951668    6960 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1758273470.951672    6960 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-09-19 09:18:25.0228 - INFO - graphrag.cli.index - Logging enabled at /content/ragtest/logs/logs.txt
# 2025-09-19 09:18:29.0131 - INFO - graphrag.index.validate_config - LLM Config Params Validated
# 2025-09-19 09:18:30.0875 - INFO - graphrag.index.validate_config - Embedding LLM Config Params Validated
# 2025-09-19 09:18:30.0875 - INFO - graphrag.cli.index - Starting pipeline run. False
# 2025-09-19 09:18:30.0876 - INFO - graphrag.cli.index - Using default configuration: {
#     "root_dir": "/content/ragtest",
#     "models": {
#         "default_chat_model": {
#             "api_key": "==== REDACTED ====",
#             "auth_type": "api_key",
#             "type": "openai_chat",
#             "model": "gpt-4o",
#             "encoding_model": "o200k_base",
#             "api_base": null,
#             "api_version": null,
#             "deployment_name": null,
#             "proxy": null,
#             "audience": null,
#             "model_supports_json": true,
#             "request_timeout": 180.0,
#             "tokens_per_minute": "auto",
#             "requests_per_minute": "auto",
#             "retry_strategy": "native",
#             "max_retries": 10,
#             "max_retry_wait": 10.0,
#             "concurrent_requests": 25,
#             "async_mode": "threaded",
#             "responses": null,
#             "max_tokens": null,
#             "temperature": 0,
#             "max_completion_tokens": null,
#             "reasoning_effort": null,
#             "top_p": 1,
#             "n": 1,
#             "frequency_penalty": 0.0,
#             "presence_penalty": 0.0
#         },
#         "default_embedding_model": {
#             "api_key": "==== REDACTED ====",
#             "auth_type": "api_key",
#             "type": "openai_embedding",
#             "model": "text-embedding-3-small",
#             "encoding_model": "cl100k_base",
#             "api_base": null,
#             "api_version": null,
#             "deployment_name": null,
#             "proxy": null,
#             "audience": null,
#             "model_supports_json": true,
#             "request_timeout": 180.0,
#             "tokens_per_minute": null,
#             "requests_per_minute": null,
#             "retry_strategy": "native",
#             "max_retries": 10,
#             "max_retry_wait": 10.0,
#             "concurrent_requests": 25,
#             "async_mode": "threaded",
#             "responses": null,
#             "max_tokens": null,
#             "temperature": 0,
#             "max_completion_tokens": null,
#             "reasoning_effort": null,
#             "top_p": 1,
#             "n": 1,
#             "frequency_penalty": 0.0,
#             "presence_penalty": 0.0
#         }
#     },
#     "input": {
#         "storage": {
#             "type": "file",
#             "base_dir": "/content/ragtest/input",
#             "storage_account_blob_url": null,
#             "cosmosdb_account_url": null
#         },
#         "file_type": "text",
#         "encoding": "utf-8",
#         "file_pattern": ".*\\.txt$",
#         "file_filter": null,
#         "text_column": "text",
#         "title_column": null,
#         "metadata": null
#     },
#     "chunks": {
#         "size": 1200,
#         "overlap": 100,
#         "group_by_columns": [
#             "id"
#         ],
#         "strategy": "tokens",
#         "encoding_model": "cl100k_base",
#         "prepend_metadata": false,
#         "chunk_size_includes_metadata": false
#     },
#     "output": {
#         "type": "file",
#         "base_dir": "/content/ragtest/output",
#         "storage_account_blob_url": null,
#         "cosmosdb_account_url": null
#     },
#     "outputs": null,
#     "update_index_output": {
#         "type": "file",
#         "base_dir": "/content/ragtest/update_output",
#         "storage_account_blob_url": null,
#         "cosmosdb_account_url": null
#     },
#     "cache": {
#         "type": "file",
#         "base_dir": "cache",
#         "storage_account_blob_url": null,
#         "cosmosdb_account_url": null
#     },
#     "reporting": {
#         "type": "file",
#         "base_dir": "/content/ragtest/logs",
#         "storage_account_blob_url": null
#     },
#     "vector_store": {
#         "default_vector_store": {
#             "type": "lancedb",
#             "db_uri": "/content/ragtest/output/lancedb",
#             "url": null,
#             "audience": null,
#             "container_name": "==== REDACTED ====",
#             "database_name": null,
#             "overwrite": true
#         }
#     },
#     "workflows": null,
#     "embed_text": {
#         "model_id": "default_embedding_model",
#         "vector_store_id": "default_vector_store",
#         "batch_size": 16,
#         "batch_max_tokens": 8191,
#         "names": [
#             "entity.description",
#             "community.full_content",
#             "text_unit.text"
#         ],
#         "strategy": null
#     },
#     "extract_graph": {
#         "model_id": "default_chat_model",
#         "prompt": "prompts/extract_graph.txt",
#         "entity_types": [
#             "organization",
#             "person",
#             "geo",
#             "event"
#         ],
#         "max_gleanings": 1,
#         "strategy": null
#     },
#     "summarize_descriptions": {
#         "model_id": "default_chat_model",
#         "prompt": "prompts/summarize_descriptions.txt",
#         "max_length": 500,
#         "max_input_tokens": 4000,
#         "strategy": null
#     },
#     "extract_graph_nlp": {
#         "normalize_edge_weights": true,
#         "text_analyzer": {
#             "extractor_type": "regex_english",
#             "model_name": "en_core_web_md",
#             "max_word_length": 15,
#             "word_delimiter": " ",
#             "include_named_entities": true,
#             "exclude_nouns": [
#                 "stuff",
#                 "thing",
#                 "things",
#                 "bunch",
#                 "bit",
#                 "bits",
#                 "people",
#                 "person",
#                 "okay",
#                 "hey",
#                 "hi",
#                 "hello",
#                 "laughter",
#                 "oh"
#             ],
#             "exclude_entity_tags": [
#                 "DATE"
#             ],
#             "exclude_pos_tags": [
#                 "DET",
#                 "PRON",
#                 "INTJ",
#                 "X"
#             ],
#             "noun_phrase_tags": [
#                 "PROPN",
#                 "NOUNS"
#             ],
#             "noun_phrase_grammars": {
#                 "PROPN,PROPN": "PROPN",
#                 "NOUN,NOUN": "NOUNS",
#                 "NOUNS,NOUN": "NOUNS",
#                 "ADJ,ADJ": "ADJ",
#                 "ADJ,NOUN": "NOUNS"
#             }
#         },
#         "concurrent_requests": 25
#     },
#     "prune_graph": {
#         "min_node_freq": 2,
#         "max_node_freq_std": null,
#         "min_node_degree": 1,
#         "max_node_degree_std": null,
#         "min_edge_weight_pct": 40.0,
#         "remove_ego_nodes": true,
#         "lcc_only": false
#     },
#     "cluster_graph": {
#         "max_cluster_size": 10,
#         "use_lcc": true,
#         "seed": 3735928559
#     },
#     "extract_claims": {
#         "enabled": false,
#         "model_id": "default_chat_model",
#         "prompt": "prompts/extract_claims.txt",
#         "description": "Any claims or facts that could be relevant to information discovery.",
#         "max_gleanings": 1,
#         "strategy": null
#     },
#     "community_reports": {
#         "model_id": "default_chat_model",
#         "graph_prompt": "prompts/community_report_graph.txt",
#         "text_prompt": "prompts/community_report_text.txt",
#         "max_length": 2000,
#         "max_input_length": 8000,
#         "strategy": null
#     },
#     "embed_graph": {
#         "enabled": false,
#         "dimensions": 1536,
#         "num_walks": 10,
#         "walk_length": 40,
#         "window_size": 2,
#         "iterations": 3,
#         "random_seed": 597832,
#         "use_lcc": true
#     },
#     "umap": {
#         "enabled": false
#     },
#     "snapshots": {
#         "embeddings": false,
#         "graphml": false,
#         "raw_graph": false
#     },
#     "local_search": {
#         "prompt": "prompts/local_search_system_prompt.txt",
#         "chat_model_id": "default_chat_model",
#         "embedding_model_id": "default_embedding_model",
#         "text_unit_prop": 0.5,
#         "community_prop": 0.15,
#         "conversation_history_max_turns": 5,
#         "top_k_entities": 10,
#         "top_k_relationships": 10,
#         "max_context_tokens": 12000
#     },
#     "global_search": {
#         "map_prompt": "prompts/global_search_map_system_prompt.txt",
#         "reduce_prompt": "prompts/global_search_reduce_system_prompt.txt",
#         "chat_model_id": "default_chat_model",
#         "knowledge_prompt": "prompts/global_search_knowledge_system_prompt.txt",
#         "max_context_tokens": 12000,
#         "data_max_tokens": 12000,
#         "map_max_length": 1000,
#         "reduce_max_length": 2000,
#         "dynamic_search_threshold": 1,
#         "dynamic_search_keep_parent": false,
#         "dynamic_search_num_repeats": 1,
#         "dynamic_search_use_summary": false,
#         "dynamic_search_max_level": 2
#     },
#     "drift_search": {
#         "prompt": "prompts/drift_search_system_prompt.txt",
#         "reduce_prompt": "prompts/drift_search_reduce_prompt.txt",
#         "chat_model_id": "default_chat_model",
#         "embedding_model_id": "default_embedding_model",
#         "data_max_tokens": 12000,
#         "reduce_max_tokens": null,
#         "reduce_temperature": 0,
#         "reduce_max_completion_tokens": null,
#         "concurrency": 32,
#         "drift_k_followups": 20,
#         "primer_folds": 5,
#         "primer_llm_max_tokens": 12000,
#         "n_depth": 3,
#         "local_search_text_unit_prop": 0.9,
#         "local_search_community_prop": 0.1,
#         "local_search_top_k_mapped_entities": 10,
#         "local_search_top_k_relationships": 10,
#         "local_search_max_data_tokens": 12000,
#         "local_search_temperature": 0,
#         "local_search_top_p": 1,
#         "local_search_n": 1,
#         "local_search_llm_max_gen_tokens": null,
#         "local_search_llm_max_gen_completion_tokens": null
#     },
#     "basic_search": {
#         "prompt": "prompts/basic_search_system_prompt.txt",
#         "chat_model_id": "default_chat_model",
#         "embedding_model_id": "default_embedding_model",
#         "k": 10,
#         "max_context_tokens": 12000
#     }
# }
# 2025-09-19 09:18:30.0877 - INFO - graphrag.api.index - Initializing indexing pipeline...
# 2025-09-19 09:18:30.0877 - INFO - graphrag.index.workflows.factory - Creating pipeline with workflows: ['load_input_documents', 'create_base_text_units', 'create_final_documents', 'extract_graph', 'finalize_graph', 'extract_covariates', 'create_communities', 'create_final_text_units', 'create_community_reports', 'generate_text_embeddings']
# 2025-09-19 09:18:30.0878 - INFO - graphrag.storage.file_pipeline_storage - Creating file storage at /content/ragtest/input
# 2025-09-19 09:18:30.0878 - INFO - graphrag.storage.file_pipeline_storage - Creating file storage at /content/ragtest/output
# 2025-09-19 09:18:30.0879 - INFO - graphrag.index.run.run_pipeline - Running standard indexing.
# 2025-09-19 09:18:30.0881 - INFO - graphrag.index.run.run_pipeline - Executing pipeline...
# 2025-09-19 09:18:30.0881 - INFO - graphrag.index.input.factory - loading input from root_dir=/content/ragtest/input
# 2025-09-19 09:18:30.0881 - INFO - graphrag.index.input.factory - Loading Input InputFileType.text
# 2025-09-19 09:18:30.0882 - INFO - graphrag.storage.file_pipeline_storage - search /content/ragtest/input for files matching .*\.txt$
# 2025-09-19 09:18:30.0898 - INFO - graphrag.index.input.util - Found 1 InputFileType.text files, loading 1
# 2025-09-19 09:18:30.0902 - INFO - graphrag.index.input.util - Total number of unfiltered InputFileType.text rows: 1
# 2025-09-19 09:18:30.0902 - INFO - graphrag.index.workflows.load_input_documents - Final # of rows loaded: 1
# 2025-09-19 09:18:30.0975 - INFO - graphrag.api.index - Workflow load_input_documents completed successfully
# 2025-09-19 09:18:31.0016 - INFO - graphrag.index.workflows.create_base_text_units - Workflow started: create_base_text_units
# 2025-09-19 09:18:31.0016 - INFO - graphrag.utils.storage - reading table from storage: documents.parquet
# 2025-09-19 09:18:31.0046 - INFO - graphrag.index.workflows.create_base_text_units - Starting chunking process for 1 documents
# 2025-09-19 09:18:31.0059 - INFO - graphrag.index.workflows.create_base_text_units - chunker progress:  1/1
# 2025-09-19 09:18:31.0105 - INFO - graphrag.index.workflows.create_base_text_units - Workflow completed: create_base_text_units
# 2025-09-19 09:18:31.0105 - INFO - graphrag.api.index - Workflow create_base_text_units completed successfully
# 2025-09-19 09:18:31.0111 - INFO - graphrag.index.workflows.create_final_documents - Workflow started: create_final_documents
# 2025-09-19 09:18:31.0112 - INFO - graphrag.utils.storage - reading table from storage: documents.parquet
# 2025-09-19 09:18:31.0116 - INFO - graphrag.utils.storage - reading table from storage: text_units.parquet
# 2025-09-19 09:18:31.0142 - INFO - graphrag.index.workflows.create_final_documents - Workflow completed: create_final_documents
# 2025-09-19 09:18:31.0142 - INFO - graphrag.api.index - Workflow create_final_documents completed successfully
# 2025-09-19 09:18:31.0150 - INFO - graphrag.index.workflows.extract_graph - Workflow started: extract_graph
# 2025-09-19 09:18:31.0150 - INFO - graphrag.utils.storage - reading table from storage: text_units.parquet
# 2025-09-19 09:19:10.0593 - INFO - graphrag.logger.progress - extract graph progress: 1/8
# 2025-09-19 09:19:12.0588 - INFO - graphrag.logger.progress - extract graph progress: 2/8
# 2025-09-19 09:19:17.0407 - INFO - graphrag.logger.progress - extract graph progress: 3/8
# 2025-09-19 09:19:22.0378 - INFO - graphrag.logger.progress - extract graph progress: 4/8
# 2025-09-19 09:19:25.0366 - INFO - graphrag.logger.progress - extract graph progress: 5/8
# 2025-09-19 09:19:37.0451 - INFO - graphrag.logger.progress - extract graph progress: 6/8
# 2025-09-19 09:19:39.0611 - INFO - graphrag.logger.progress - extract graph progress: 7/8
# 2025-09-19 09:20:54.0780 - INFO - graphrag.logger.progress - extract graph progress: 8/8
# 2025-09-19 09:20:54.0897 - INFO - graphrag.logger.progress - Summarize entity/relationship description progress: 1/206
# 2025-09-19 09:20:54.0897 - INFO - graphrag.logger.progress - Summarize entity/relationship description progress: 2/206
# 2025-09-19 09:20:54.0898 - INFO - graphrag.logger.progress - Summarize entity/relationship description progress: 3/206
# 2025-09-19 09:20:54.0898 - INFO - graphrag.logger.progress - Summarize entity/relationship description progress: 4/206
# 2025-09-19 09:20:54.0898 - INFO - graphrag.logger.progress - Summarize entity/relationship description progress: 5/206
# 2025-09-19 09:20:54.0898 - INFO - graphrag.logger.progress - Summarize entity/relationship description progress: 6/206
# 2025-09-19 09:20:54.0898 - INFO - graphrag.logger.progress - Summarize entity/relationship description progress: 7/206
# 2025-09-19 09:20:54.0898 - INFO - graphrag.logger.progress - Summarize entity/relationship description progress: 8/206
# 2025-09-19 09:20:54.0898 - INFO - graphrag.logger.progress - Summarize entity/relationship description progress: 9/206
# 2025-09-19 09:20:54.0901 - INFO - graphrag.logger.progress - Summarize entity/relationship description progress: 10/206
# 2025-09-19 09:20:54.0902 - INFO - graphrag.logger.progress - Summarize entity/relationship description progress: 11/206
# 2025-09-19 09:20:54.0904 - INFO - graphrag.logger.progress - Summarize entity/relationship description progress: 12/206
# 2025-09-19 09:20:54.0904 - INFO - graphrag.logger.progress - Summarize entity/relationship description progress: 13/206
# 2025-09-19 09:20:54.0904 - INFO - graphrag.logger.progress - Summarize entity/relationship description progress: 14/206
# 2025-09-19 09:20:54.0905 - INFO - graphrag.logger.progress - Summarize entity/relationship description progress: 15/206
# 2025-09-19 09:20:54.0905 - INFO - graphrag.logger.progress - Summarize entity/relationship description progress: 16/206
# 2025-09-19 09:20:54.0905 - INFO - graphrag.logger.progress - Summarize entity/relationship description progress:
- INFO - graphrag.logger.progress - Summarize entity/relationship description progress: 206/206
# 2025-09-19 09:21:08.0287 - INFO - graphrag.index.workflows.extract_graph - Workflow completed: extract_graph
# 2025-09-19 09:21:08.0287 - INFO - graphrag.api.index - Workflow extract_graph completed successfully
# 2025-09-19 09:21:08.0318 - INFO - graphrag.index.workflows.finalize_graph - Workflow started: finalize_graph
# 2025-09-19 09:21:08.0319 - INFO - graphrag.utils.storage - reading table from storage: entities.parquet
# 2025-09-19 09:21:08.0326 - INFO - graphrag.utils.storage - reading table from storage: relationships.parquet
# 2025-09-19 09:21:08.0372 - INFO - graphrag.index.workflows.finalize_graph - Workflow completed: finalize_graph
# 2025-09-19 09:21:08.0372 - INFO - graphrag.api.index - Workflow finalize_graph completed successfully
# 2025-09-19 09:21:08.0396 - INFO - graphrag.index.workflows.extract_covariates - Workflow started: extract_covariates
# 2025-09-19 09:21:08.0396 - INFO - graphrag.index.workflows.extract_covariates - Workflow completed: extract_covariates
# 2025-09-19 09:21:08.0396 - INFO - graphrag.api.index - Workflow extract_covariates completed successfully
# 2025-09-19 09:21:08.0396 - INFO - graphrag.index.workflows.create_communities - Workflow started: create_communities
# 2025-09-19 09:21:08.0397 - INFO - graphrag.utils.storage - reading table from storage: entities.parquet
# 2025-09-19 09:21:08.0403 - INFO - graphrag.utils.storage - reading table from storage: relationships.parquet
# 2025-09-19 09:21:08.0526 - INFO - graphrag.index.workflows.create_communities - Workflow completed: create_communities
# 2025-09-19 09:21:08.0527 - INFO - graphrag.api.index - Workflow create_communities completed successfully
# 2025-09-19 09:21:08.0566 - INFO - graphrag.index.workflows.create_final_text_units - Workflow started: create_final_text_units
# 2025-09-19 09:21:08.0567 - INFO - graphrag.utils.storage - reading table from storage: text_units.parquet
# 2025-09-19 09:21:08.0572 - INFO - graphrag.utils.storage - reading table from storage: entities.parquet
# 2025-09-19 09:21:08.0578 - INFO - graphrag.utils.storage - reading table from storage: relationships.parquet
# 2025-09-19 09:21:08.0637 - INFO - graphrag.index.workflows.create_final_text_units - Workflow completed: create_final_text_units
# 2025-09-19 09:21:08.0638 - INFO - graphrag.api.index - Workflow create_final_text_units completed successfully
# 2025-09-19 09:21:08.0658 - INFO - graphrag.index.workflows.create_community_reports - Workflow started: create_community_reports
# 2025-09-19 09:21:08.0658 - INFO - graphrag.utils.storage - reading table from storage: relationships.parquet
# 2025-09-19 09:21:08.0664 - INFO - graphrag.utils.storage - reading table from storage: entities.parquet
# 2025-09-19 09:21:08.0669 - INFO - graphrag.utils.storage - reading table from storage: communities.parquet
# 2025-09-19 09:21:08.0694 - INFO - graphrag.index.operations.summarize_communities.graph_context.context_builder - Number of nodes at level=2 => 22
# 2025-09-19 09:21:08.0801 - INFO - graphrag.index.operations.summarize_communities.graph_context.context_builder - Number of nodes at level=1 => 61
# 2025-09-19 09:21:08.0948 - INFO - graphrag.index.operations.summarize_communities.graph_context.context_builder - Number of nodes at level=0 => 83
# 2025-09-19 09:21:48.0615 - INFO - graphrag.logger.progress - level 2 summarize communities progress: 1/2
# 2025-09-19 09:22:09.0907 - INFO - graphrag.logger.progress - level 2 summarize communities progress: 2/2
# 2025-09-19 09:22:23.0912 - INFO - graphrag.logger.progress - level 1 summarize communities progress: 1/12
# 2025-09-19 09:22:24.0288 - INFO - graphrag.logger.progress - level 1 summarize communities progress: 2/12
# 2025-09-19 09:22:24.0966 - INFO - graphrag.logger.progress - level 1 summarize communities progress: 3/12
# 2025-09-19 09:22:24.0970 - INFO - graphrag.logger.progress - level 1 summarize communities progress: 4/12
# 2025-09-19 09:22:25.0070 - INFO - graphrag.logger.progress - level 1 summarize communities progress: 5/12
# 2025-09-19 09:22:25.0217 - INFO - graphrag.logger.progress - level 1 summarize communities progress: 6/12
# 2025-09-19 09:22:25.0286 - INFO - graphrag.logger.progress - level 1 summarize communities progress: 7/12
# 2025-09-19 09:22:26.0675 - INFO - graphrag.logger.progress - level 1 summarize communities progress: 8/12
# 2025-09-19 09:22:36.0850 - INFO - graphrag.logger.progress - level 1 summarize communities progress: 9/12
# 2025-09-19 09:22:38.0022 - INFO - graphrag.logger.progress - level 1 summarize communities progress: 10/12
# 2025-09-19 09:22:38.0474 - INFO - graphrag.logger.progress - level 1 summarize communities progress: 11/12
# 2025-09-19 09:22:41.0924 - INFO - graphrag.logger.progress - level 1 summarize communities progress: 12/12
# 2025-09-19 09:22:53.0543 - INFO - graphrag.logger.progress - level 0 summarize communities progress: 1/8
# 2025-09-19 09:22:56.0675 - INFO - graphrag.logger.progress - level 0 summarize communities progress: 2/8
# 2025-09-19 09:22:59.0258 - INFO - graphrag.logger.progress - level 0 summarize communities progress: 3/8
# 2025-09-19 09:22:59.0372 - INFO - graphrag.logger.progress - level 0 summarize communities progress: 4/8
# 2025-09-19 09:23:00.0145 - INFO - graphrag.logger.progress - level 0 summarize communities progress: 5/8
# 2025-09-19 09:23:00.0257 - INFO - graphrag.logger.progress - level 0 summarize communities progress: 6/8
# 2025-09-19 09:23:19.0088 - INFO - graphrag.logger.progress - level 0 summarize communities progress: 7/8
# 2025-09-19 09:23:20.0465 - INFO - graphrag.logger.progress - level 0 summarize communities progress: 8/8
# 2025-09-19 09:23:20.0478 - INFO - graphrag.index.workflows.create_community_reports - Workflow completed: create_community_reports
# 2025-09-19 09:23:20.0478 - INFO - graphrag.api.index - Workflow create_community_reports completed successfully
# 2025-09-19 09:23:20.0506 - INFO - graphrag.index.workflows.generate_text_embeddings - Workflow started: generate_text_embeddings
# 2025-09-19 09:23:20.0507 - INFO - graphrag.utils.storage - reading table from storage: documents.parquet
# 2025-09-19 09:23:20.0511 - INFO - graphrag.utils.storage - reading table from storage: relationships.parquet
# 2025-09-19 09:23:20.0517 - INFO - graphrag.utils.storage - reading table from storage: text_units.parquet
# 2025-09-19 09:23:20.0521 - INFO - graphrag.utils.storage - reading table from storage: entities.parquet
# 2025-09-19 09:23:20.0525 - INFO - graphrag.utils.storage - reading table from storage: community_reports.parquet
# 2025-09-19 09:23:20.0537 - INFO - graphrag.index.workflows.generate_text_embeddings - Creating embeddings
# 2025-09-19 09:23:20.0537 - INFO - graphrag.index.operations.embed_text.embed_text - using vector store lancedb with container_name default for embedding entity.description: default-entity-description
# 2025-09-19 09:23:20.0540 - INFO - graphrag.index.operations.embed_text.embed_text - uploading text embeddings batch 1/1 of size 500 to vector store
# 2025-09-19 09:23:20.0608 - INFO - graphrag.index.operations.embed_text.strategies.openai - embedding 90 inputs via 90 snippets using 6 batches. max_batch_size=16, batch_max_tokens=8191
# 2025-09-19 09:23:21.0238 - INFO - graphrag.logger.progress - generate embeddings progress: 1/6
# 2025-09-19 09:23:21.0242 - INFO - graphrag.logger.progress - generate embeddings progress: 2/6
# 2025-09-19 09:23:21.0332 - INFO - graphrag.logger.progress - generate embeddings progress: 3/6
# 2025-09-19 09:23:21.0376 - INFO - graphrag.logger.progress - generate embeddings progress: 4/6
# 2025-09-19 09:23:21.0729 - INFO - graphrag.logger.progress - generate embeddings progress: 5/6
# 2025-09-19 09:23:22.0103 - INFO - graphrag.logger.progress - generate embeddings progress: 6/6
# [2025-09-19T09:23:22Z WARN  lance::dataset::write::insert] No existing dataset at /content/ragtest/output/lancedb/default-entity-description.lance, it will be created
# 2025-09-19 09:23:22.0133 - INFO - graphrag.index.operations.embed_text.embed_text - using vector store lancedb with container_name default for embedding community.full_content: default-community-full_content
# 2025-09-19 09:23:22.0134 - INFO - graphrag.index.operations.embed_text.embed_text - uploading text embeddings batch 1/1 of size 500 to vector store
# 2025-09-19 09:23:22.0153 - INFO - graphrag.index.operations.embed_text.strategies.openai - embedding 22 inputs via 22 snippets using 2 batches. max_batch_size=16, batch_max_tokens=8191
# 2025-09-19 09:23:22.0730 - INFO - graphrag.logger.progress - generate embeddings progress: 1/2
# 2025-09-19 09:23:23.0172 - INFO - graphrag.logger.progress - generate embeddings progress: 2/2
# [2025-09-19T09:23:23Z WARN  lance::dataset::write::insert] No existing dataset at /content/ragtest/output/lancedb/default-community-full_content.lance, it will be created
# 2025-09-19 09:23:23.0183 - INFO - graphrag.index.operations.embed_text.embed_text - using vector store lancedb with container_name default for embedding text_unit.text: default-text_unit-text
# 2025-09-19 09:23:23.0185 - INFO - graphrag.index.operations.embed_text.embed_text - uploading text embeddings batch 1/1 of size 500 to vector store
# 2025-09-19 09:23:23.0201 - INFO - graphrag.index.operations.embed_text.strategies.openai - embedding 8 inputs via 8 snippets using 2 batches. max_batch_size=16, batch_max_tokens=8191
# 2025-09-19 09:23:23.0928 - INFO - graphrag.logger.progress - generate embeddings progress: 1/2
# 2025-09-19 09:23:24.0046 - INFO - graphrag.logger.progress - generate embeddings progress: 2/2
# [2025-09-19T09:23:24Z WARN  lance::dataset::write::insert] No existing dataset at /content/ragtest/output/lancedb/default-text_unit-text.lance, it will be created
# 2025-09-19 09:23:24.0053 - INFO - graphrag.index.workflows.generate_text_embeddings - Workflow completed: generate_text_embeddings
# 2025-09-19 09:23:24.0053 - INFO - graphrag.api.index - Workflow generate_text_embeddings completed successfully
# 2025-09-19 09:23:24.0095 - INFO - graphrag.index.run.run_pipeline - Indexing pipeline complete.
# 2025-09-19 09:23:24.0099 - INFO - graphrag.cli.index - All workflows completed successfully.

# %%
# Global Search

# !python -m graphrag query \
           --root ./ragtest \
           --method global \
           --query " what this text document about?"
# Out:
# 2025-09-19 09:23:39.128703: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1758273819.154012    8427 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1758273819.161668    8427 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1758273819.182323    8427 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1758273819.182364    8427 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1758273819.182369    8427 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1758273819.182373    8427 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-09-19 09:23:52.0041 - INFO - graphrag.storage.file_pipeline_storage - Creating file storage at /content/ragtest/output
# 2025-09-19 09:23:52.0043 - INFO - graphrag.utils.storage - reading table from storage: entities.parquet
# 2025-09-19 09:23:52.0056 - INFO - graphrag.utils.storage - reading table from storage: communities.parquet
# 2025-09-19 09:23:52.0062 - INFO - graphrag.utils.storage - reading table from storage: community_reports.parquet
# 2025-09-19 09:24:39.0373 - INFO - graphrag.cli.query - Global Search Response:
# The document provides a comprehensive overview of advancements and research in the field of natural language processing (NLP), with a particular focus on several key models and methodologies. It discusses models such as LoRA, GPT-3, RoBERTa, and GPT-2, along with their associated datasets and evaluation benchmarks [Data: Reports (0, 10, 2, 12, 4, +more)].
#
# ### GPT-3 and Transformer Architecture
#
# A significant portion of the document is dedicated to GPT-3, a large language model developed by OpenAI based on the Transformer architecture. It highlights the development and impact of GPT-3, emphasizing the roles of key entities such as the NVIDIA Tesla V100 GPU and the Adam optimization algorithm, which are crucial for supporting GPT-3's development and performance [Data: Reports (3, 16)]. The contributions of foundational researchers like Brown et al. and Vaswani et al. are also acknowledged for their pivotal roles in advancing AI technology [Data: Reports (3, 16)].
#
# ### LoRA (Low-Rank Adaptation)
#
# LoRA is another focal point, described as a method to enhance the efficiency of pre-trained language models by injecting trainable rank decomposition matrices into each layer of the Transformer architecture. This method is particularly significant for adapting large models like GPT-3 [Data: Reports (0, 8, 6, 19)]. The document also covers the contributions of researchers such as Aghajanyan et al., Hambardzumyan et al., and Lester et al., who have significantly influenced the development and theoretical foundation of LoRA [Data: Reports (0, 8, 6, 19, 20)].
#
# ### RoBERTa and Evaluation Benchmarks
#
# RoBERTa, a robustly optimized BERT approach, is discussed for its superior performance in NLP tasks and its evaluation using the GLUE benchmark [Data: Reports (10)]. The document also mentions the role of datasets like WebNLG, DART, and SAMSum in evaluating the performance of language models like GPT-2 and GPT-3, highlighting their importance in advancing NLP technologies [Data: Reports (2, 12, 4, 13, 14)].
#
# ### Computational Resources
#
# The document emphasizes the importance of computational resources, particularly the NVIDIA Tesla V100 GPU, in providing the necessary power for running large-scale experiments on GPT-3. This highlights the critical role of hardware in AI research and development [Data: Reports (3, 16)].
#
# Overall, the document serves as a detailed exploration of current trends and innovations in NLP, focusing on the development, application, and evaluation of advanced language models and the computational infrastructure that supports them.

# %%
# Local search

# !python -m graphrag query \
           --root ./ragtest \
           --method local \
           --query " what this Low Rank Adaptation"
# Out:
# 2025-09-19 09:24:51.123792: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1758273891.157581    8737 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1758273891.164839    8737 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1758273891.184152    8737 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1758273891.184225    8737 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1758273891.184232    8737 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1758273891.184238    8737 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-09-19 09:25:03.0717 - INFO - graphrag.storage.file_pipeline_storage - Creating file storage at /content/ragtest/output
# 2025-09-19 09:25:03.0719 - INFO - graphrag.utils.storage - reading table from storage: communities.parquet
# 2025-09-19 09:25:03.0729 - INFO - graphrag.utils.storage - reading table from storage: community_reports.parquet
# 2025-09-19 09:25:03.0737 - INFO - graphrag.utils.storage - reading table from storage: text_units.parquet
# 2025-09-19 09:25:03.0744 - INFO - graphrag.utils.storage - reading table from storage: relationships.parquet
# 2025-09-19 09:25:03.0750 - INFO - graphrag.utils.storage - reading table from storage: entities.parquet
# 2025-09-19 09:25:25.0758 - INFO - graphrag.cli.query - Local Search Response:
# # Understanding Low-Rank Adaptation (LoRA)
#
# Low-Rank Adaptation (LoRA) is an innovative method designed to enhance the efficiency and adaptability of pre-trained language models, particularly those based on the Transformer architecture. The core idea behind LoRA is to inject trainable rank decomposition matrices into each layer of a Transformer model, allowing for efficient updates and modifications without the need to retrain the entire model from scratch. This approach optimizes computational resources while maintaining the model's performance, making it a valuable tool in the field of natural language processing (NLP) [Data: Entities (9); Reports (0)].
#
# ## Key Features and Benefits
#
# LoRA is particularly beneficial for large models like GPT-3, as it reduces the number of trainable parameters significantly, thereby optimizing computational resources. This method allows for efficient adaptation without the need for extensive retraining, which is crucial for managing large models' computational demands. By focusing on reducing the number of trainable parameters, LoRA minimizes the computational resources required while maintaining the model's performance. This makes it especially useful in scenarios where resource management is critical [Data: Reports (0); Relationships (10, 72)].
#
# ## Theoretical Foundations and Collaborations
#
# The development of LoRA is supported by theoretical insights into low-rank structures in machine learning. Researchers like Aghajanyan et al. and Allen-Zhu & Li have contributed to the theoretical foundation of LoRA, demonstrating that pre-trained language models have a low intrinsic dimension, which inspired the development of this method. This connection underscores the importance of theoretical insights in driving practical advancements in NLP technologies [Data: Reports (0); Relationships (27, 105)].
#
# ## Applications and Impact
#
# LoRA has been applied to various models, including GPT-3, RoBERTa, and DeBERTa, demonstrating its effectiveness in maintaining or even enhancing model performance across different tasks. The method has been evaluated on datasets like MNLI-matched and WikiSQL, further validating its utility in enhancing the adaptability of pre-trained models. By improving the adaptability and performance of large language models, LoRA has the potential to significantly impact the field of AI technology, leading to more advanced and capable AI systems [Data: Reports (0, 6); Relationships (82, 81, 11, 12)].
#
# In summary, Low-Rank Adaptation is a method that leverages low-rank structures to optimize the adaptation of large language models, offering a more efficient and effective alternative to traditional fine-tuning methods. Its development and application highlight the collaborative efforts of researchers and the importance of theoretical foundations in advancing AI technologies.

# %% [markdown]
# ### Important Note: You must update the file path based on your implementation as the file name <time stamp> change with each implementation. You can also visualize the Parquet file using Pandas.

# %%
import duckdb

# Query the Parquet file

query_result = duckdb.query("SELECT * FROM '/content/ragtest/output/entities.parquet'")
print(query_result)
# Out:
# ┌──────────────────────────────────────┬───────────────────┬───────────────────────┬──────────────┬──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬───────────┬────────┬────────┬────────┐
# │                  id                  │ human_readable_id │         title         │     type     │                                                                                                                                                                                                                                                                                                                   description                                                                                                                                                                                                                                                                                                                    │                                                                                                                            text_unit_ids                                                                                                                             │ frequency │ degree │   x    │   y    │
# │               varchar                │       int64       │        varchar        │   varchar    │                                                                                                                                                                                                                                                                                                                     varchar                                                                                                                                                                                                                                                                                                                      │                                                                                                                              varchar[]                                                                                                                               │   int64   │ int64  │ double │ double │
# ├──────────────────────────────────────┼───────────────────┼───────────────────────┼──────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────┼────────┼────────┼────────┤
# │ ab13673c-b0c5-4b73-8b2d-2c7375dd1eb7 │                 0 │ EDWARD HU             │ PERSON       │ Edward Hu is one of the authors of the paper on Low-Rank Adaptation of Large Language Models                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     │
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          │ [d41586ca56e15b24492d9ef0d1cf60d77954a132dddc3f6ca2d1e9703d5c3477ed440442d667486de11631ec5f18e8c8d880db8c7c500dd65746e9e2ce1b640a]                                                                                                                                   │         1 │      9 │    0.0 │    0.0 │
# │ 4394e43c-020c-4df3-a520-d50b8cafd7a1 │                 9 │ LORA                  │ EVENT        │ LoRA, which stands for Low-Rank Adaptation, is a method designed to enhance the efficiency and interpretability of pre-trained language models. This innovative approach involves the injection of trainable rank decomposition matrices into each layer of the Transformer architecture. By doing so, LoRA effectively adapts large language models, allowing for more efficient updates and modifications without the need to retrain the entire model from scratch. This method not only optimizes computational resources but also maintains the model's performance, making it a valuable tool in the field of natural language processing. │ [d41586ca56e15b24492d9ef0d1cf60d77954a132dddc3f6ca2d1e9703d5c3477ed440442d667486de11631ec5f18e8c8d880db8c7c500dd65746e9e2ce1b640a, 14542facc7bca54ac03efd874772d9ac87553a713ec6acda8dcbc36eb377443c5121e7e09c7e0add6b25b9e65932e4b1fb46544a980140e966e0d872e1cc16fb] │         2 │     37 │    0.0 │    0.0 │
# │                  ·                   │                 · │  ·                    │   ·          │                                              ·                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   │                                                                 ·                                                                                                                                                                                                    │         · │      · │     ·  │     ·  │
# │                  ·                   │                 · │  ·                    │   ·          │                                              ·                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   │                                                                 ·                                                                                                                                                                                                    │         · │      · │     ·  │     ·  │
# │                  ·                   │                 · │  ·                    │   ·          │                                              ·                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   │                                                                 ·                                                                                                                                                                                                    │         · │      · │     ·  │     ·  │
# │ 914ed01c-cf67-4944-b874-d96450269630 │                80 │ ZHAO ET AL.           │ PERSON       │ Zhao et al. are researchers known for their work on low-rank constraints in neural networks                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      │ [683495fea12abcf4d6f96d49a4f03bd91021735476b2e787a6e482ceb88fa0869c1d8b487dce4c6e3f2b9fbbf3ff69e0bc78684f60bfe4034340ce1d554e57d9]                                                                                                                                   │         1 │      1 │    0.0 │    0.0 │
# │ 2d3917ed-c058-4b7b-abb0-a954b0815644 │                81 │ KHODAK ET AL.         │ PERSON       │ Khodak et al. are researchers known for their contributions to low-rank constraints in neural networks                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           │ [683495fea12abcf4d6f96d49a4f03bd91021735476b2e787a6e482ceb88fa0869c1d8b487dce4c6e3f2b9fbbf3ff69e0bc78684f60bfe4034340ce1d554e57d9]                                                                                                                                   │         1 │      1 │    0.0 │    0.0 │
# │ 3d75d806-22e9-4d31-88ba-1198d0ac68c0 │                82 │ DENIL ET AL.          │ PERSON       │ Denil et al. are researchers known for their work on low-rank constraints in neural networks                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     │ [683495fea12abcf4d6f96d49a4f03bd91021735476b2e787a6e482ceb88fa0869c1d8b487dce4c6e3f2b9fbbf3ff69e0bc78684f60bfe4034340ce1d554e57d9]                                                                                                                                   │         1 │      1 │    0.0 │    0.0 │
# │ 3c825c0a-7154-4f1d-bf88-65b05e4cc34f │                83 │ ALLEN-ZHU ET AL.      │ PERSON       │ Allen-Zhu et al. are researchers known for their theoretical work on neural networks and low-rank structures                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     │ [683495fea12abcf4d6f96d49a4f03bd91021735476b2e787a6e482ceb88fa0869c1d8b487dce4c6e3f2b9fbbf3ff69e0bc78684f60bfe4034340ce1d554e57d9]                                                                                                                                   │         1 │      1 │    0.0 │    0.0 │
# │ db960848-008f-4ed9-b8f7-57b15be6b4c6 │                84 │ GHORBANI ET AL.       │ PERSON       │ Ghorbani et al. are researchers known for their theoretical work on neural networks and low-rank structures                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      │ [683495fea12abcf4d6f96d49a4f03bd91021735476b2e787a6e482ceb88fa0869c1d8b487dce4c6e3f2b9fbbf3ff69e0bc78684f60bfe4034340ce1d554e57d9]                                                                                                                                   │         1 │      1 │    0.0 │    0.0 │
# │ 3e9bc9ff-5409-40f1-9623-491ff205b2d5 │                85 │ REBFFI ET AL.         │              │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  │ [683495fea12abcf4d6f96d49a4f03bd91021735476b2e787a6e482ceb88fa0869c1d8b487dce4c6e3f2b9fbbf3ff69e0bc78684f60bfe4034340ce1d554e57d9]                                                                                                                                   │         1 │      1 │    0.0 │    0.0 │
# │ 0d8d6a52-3712-46fc-9b19-01bfd446b478 │                86 │ OPENAI                │ ORGANIZATION │ OpenAI is the organization that developed GPT-3, a large Transformer language model                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              │ [683495fea12abcf4d6f96d49a4f03bd91021735476b2e787a6e482ceb88fa0869c1d8b487dce4c6e3f2b9fbbf3ff69e0bc78684f60bfe4034340ce1d554e57d9]                                                                                                                                   │         1 │      1 │    0.0 │    0.0 │
# │ 46ad981d-42c5-4343-a8a3-a0fc66a1d4b6 │                87 │ COMPACTER             │              │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  │ [683495fea12abcf4d6f96d49a4f03bd91021735476b2e787a6e482ceb88fa0869c1d8b487dce4c6e3f2b9fbbf3ff69e0bc78684f60bfe4034340ce1d554e57d9]                                                                                                                                   │         1 │      1 │    0.0 │    0.0 │
# │ a1dd73a8-84ad-4bef-97ed-12542fcf5a35 │                88 │ ALLEN-ZHU & LI        │ PERSON       │ Allen-Zhu & Li are researchers who have published theoretical results on low-rank adaptations and adversarial training                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           │ [14542facc7bca54ac03efd874772d9ac87553a713ec6acda8dcbc36eb377443c5121e7e09c7e0add6b25b9e65932e4b1fb46544a980140e966e0d872e1cc16fb]                                                                                                                                   │         1 │      1 │    0.0 │    0.0 │
# │ 4c68be42-d7ae-4eeb-bf18-16505b769004 │                89 │ NLP                   │ EVENT        │ NLP, or Natural Language Processing, is a field of study focused on the interaction between computers and human language, and is a critical topic in the context of using pre-trained language models for downstream tasks                                                                                                                                                                                                                                                                                                                                                                                                                       │ [14542facc7bca54ac03efd874772d9ac87553a713ec6acda8dcbc36eb377443c5121e7e09c7e0add6b25b9e65932e4b1fb46544a980140e966e0d872e1cc16fb]                                                                                                                                   │         1 │      1 │    0.0 │    0.0 │
# ├──────────────────────────────────────┴───────────────────┴───────────────────────┴──────────────┴──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴───────────┴────────┴────────┴────────┤
# │ 90 rows (20 shown)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    10 columns │
# └──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
ORGANIZATION_result = duckdb.query("""
    SELECT *
    FROM '/content/ragtest/output/entities.parquet'
    WHERE type = 'EVENT'
""")

# Print the result
print(ORGANIZATION_result)
# Out:
# ┌──────────────────────────────────────┬───────────────────┬───────────────────────────────┬─────────┬──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬───────────┬────────┬────────┬────────┐
# │                  id                  │ human_readable_id │             title             │  type   │                                                                                                                                                                                                                                                                                                                                                                                   description                                                                                                                                                                                                                                                                                                                                                                                    │                                                                                                                                                                                             text_unit_ids                                                                                                                                                                                              │ frequency │ degree │   x    │   y    │
# │               varchar                │       int64       │            varchar            │ varchar │                                                                                                                                                                                                                                                                                                                                                                                     varchar                                                                                                                                                                                                                                                                                                                                                                                      │                                                                                                                                                                                               varchar[]                                                                                                                                                                                                │   int64   │ int64  │ double │ double │
# ├──────────────────────────────────────┼───────────────────┼───────────────────────────────┼─────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────┼────────┼────────┼────────┤
# │ 4394e43c-020c-4df3-a520-d50b8cafd7a1 │                 9 │ LORA                          │ EVENT   │ LoRA, which stands for Low-Rank Adaptation, is a method designed to enhance the efficiency and interpretability of pre-trained language models. This innovative approach involves the injection of trainable rank decomposition matrices into each layer of the Transformer architecture. By doing so, LoRA effectively adapts large language models, allowing for more efficient updates and modifications without the need to retrain the entire model from scratch. This method not only optimizes computational resources but also maintains the model's performance, making it a valuable tool in the field of natural language processing.                                                                                                                                 │ [d41586ca56e15b24492d9ef0d1cf60d77954a132dddc3f6ca2d1e9703d5c3477ed440442d667486de11631ec5f18e8c8d880db8c7c500dd65746e9e2ce1b640a, 14542facc7bca54ac03efd874772d9ac87553a713ec6acda8dcbc36eb377443c5121e7e09c7e0add6b25b9e65932e4b1fb46544a980140e966e0d872e1cc16fb]                                                                                                                                   │         2 │     37 │    0.0 │    0.0 │
# │ 44aecd7c-698c-4fa5-8684-6c7d20a12c22 │                21 │ SUMMARIZATION                 │ EVENT   │ Summarization is a task in language modeling where the content of an article is condensed into a brief summary                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   │ [a0f933e8fcb74fdedab758c6d42f240c7c551ee5885ec9eef8e48dc2bb5a19826253b7205adbbd5367245ed2f790ccab7af711d2187766c8576a7222dd4d8f5b]                                                                                                                                                                                                                                                                     │         1 │      1 │    0.0 │    0.0 │
# │ e1197075-f508-4b2d-92c4-04fe215096d4 │                22 │ MACHINE READING COMPREHENSION │ EVENT   │ Machine Reading Comprehension (MRC) is a task where models answer questions based on a given text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                │ [a0f933e8fcb74fdedab758c6d42f240c7c551ee5885ec9eef8e48dc2bb5a19826253b7205adbbd5367245ed2f790ccab7af711d2187766c8576a7222dd4d8f5b]                                                                                                                                                                                                                                                                     │         1 │      1 │    0.0 │    0.0 │
# │ 38013780-eef9-4a70-a62e-76a69a6f8461 │                41 │ GLUE                          │ EVENT   │ GLUE is a benchmark designed to evaluate the performance of natural language understanding models, including prominent models such as RoBERTa and DeBERTa. It serves as a comprehensive tool for assessing the capabilities of various models in understanding and processing human language, providing a standardized framework for comparison and improvement in the field of natural language processing.                                                                                                                                                                                                                                                                                                                                                                     │ [dc117861cc54f455507c591bc07446467b86a5130e17795adc1f8c3063f1e5bd4ce5e2596d724131f0b03557115a13fdcdbb6fc3899b12a17c8dc5dad06d86ba, 9008a87258d6704755ee05a165b55cb5ae4b3d576e8c6426717913d3ac515534899a936748bada7a93e32caa151dbc8ebf2e4c0a90bab85f718cb29df9667d48]                                                                                                                                   │         2 │      7 │    0.0 │    0.0 │
# │ 0e698ce2-bc1c-4057-b584-4e22a9fb56d0 │                42 │ WIKISQL                       │ EVENT   │ WikiSQL is a benchmark dataset specifically designed to evaluate the performance of language models on SQL query generation tasks. It serves as a critical resource for researchers and developers aiming to enhance the capabilities of language models in understanding and generating SQL queries from natural language inputs. WikiSQL is utilized in large-scale experiments, including those involving advanced models like GPT-3, to assess and improve their proficiency in translating natural language into structured SQL queries. This dataset plays a pivotal role in advancing the field of natural language processing by providing a standardized platform for testing and comparing the effectiveness of various models in handling SQL query generation tasks. │ [dc117861cc54f455507c591bc07446467b86a5130e17795adc1f8c3063f1e5bd4ce5e2596d724131f0b03557115a13fdcdbb6fc3899b12a17c8dc5dad06d86ba, 9008a87258d6704755ee05a165b55cb5ae4b3d576e8c6426717913d3ac515534899a936748bada7a93e32caa151dbc8ebf2e4c0a90bab85f718cb29df9667d48, 683495fea12abcf4d6f96d49a4f03bd91021735476b2e787a6e482ceb88fa0869c1d8b487dce4c6e3f2b9fbbf3ff69e0bc78684f60bfe4034340ce1d554e57d9] │         3 │      4 │    0.0 │    0.0 │
# │ e0910b02-30b6-4168-92b7-9521f6a5301d │                43 │ SAMSUM                        │ EVENT   │ SAMSum is a dataset specifically designed for the task of conversation summarization. It is utilized in experiments involving advanced language models such as GPT-3. The primary purpose of the SAMSum dataset is to evaluate and enhance the performance of models tasked with summarizing dialogues. By providing a structured collection of conversational data, SAMSum serves as a critical resource for researchers and developers aiming to improve the accuracy and efficiency of dialogue summarization technologies.                                                                                                                                                                                                                                                   │ [dc117861cc54f455507c591bc07446467b86a5130e17795adc1f8c3063f1e5bd4ce5e2596d724131f0b03557115a13fdcdbb6fc3899b12a17c8dc5dad06d86ba, 9008a87258d6704755ee05a165b55cb5ae4b3d576e8c6426717913d3ac515534899a936748bada7a93e32caa151dbc8ebf2e4c0a90bab85f718cb29df9667d48]                                                                                                                                   │         2 │      3 │    0.0 │    0.0 │
# │ a1ab2ef5-e20e-497c-91e8-de7823681220 │                51 │ GLUE BENCHMARK                │ EVENT   │ The GLUE benchmark is a set of tasks used to evaluate the performance of NLP models                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              │ [fe2bd7fb47024616741a7859c86ef5360d3d8fd60112b3d9aab9d2d44af03bfc907170c58bf95cab86f0b2033b8f411582b2ac20e22ce57f9b19bfd17f0be16c]                                                                                                                                                                                                                                                                     │         1 │      1 │    0.0 │    0.0 │
# │ 2a21f1ce-d55b-40d0-8eb5-aa090c9a3c65 │                59 │ SUPERGLUE                     │ EVENT   │ SuperGLUE is an advanced benchmark for evaluating natural language understanding models, building on the original GLUE benchmark                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 │ [9008a87258d6704755ee05a165b55cb5ae4b3d576e8c6426717913d3ac515534899a936748bada7a93e32caa151dbc8ebf2e4c0a90bab85f718cb29df9667d48]                                                                                                                                                                                                                                                                     │         1 │      2 │    0.0 │    0.0 │
# │ e0ff6b6b-6f38-4bc8-a98b-254a31ae9885 │                60 │ MNLI                          │ EVENT   │ MNLI (Multi-Genre Natural Language Inference) is a dataset used to evaluate natural language inference models                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    │ [9008a87258d6704755ee05a165b55cb5ae4b3d576e8c6426717913d3ac515534899a936748bada7a93e32caa151dbc8ebf2e4c0a90bab85f718cb29df9667d48]                                                                                                                                                                                                                                                                     │         1 │      1 │    0.0 │    0.0 │
# │ 908adcfc-1c47-47ae-9b27-c3bbc133c6e3 │                61 │ COLA                          │ EVENT   │ CoLA (Corpus of Linguistic Acceptability) is a dataset used to evaluate linguistic acceptability in models                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       │ [9008a87258d6704755ee05a165b55cb5ae4b3d576e8c6426717913d3ac515534899a936748bada7a93e32caa151dbc8ebf2e4c0a90bab85f718cb29df9667d48]                                                                                                                                                                                                                                                                     │         1 │      1 │    0.0 │    0.0 │
# │ 0a8c35ec-11db-4dc5-8083-cad03279bf5e │                62 │ STS-B                         │ EVENT   │ STS-B (Semantic Textual Similarity Benchmark) is a dataset used to evaluate the semantic similarity between text pairs                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           │ [9008a87258d6704755ee05a165b55cb5ae4b3d576e8c6426717913d3ac515534899a936748bada7a93e32caa151dbc8ebf2e4c0a90bab85f718cb29df9667d48]                                                                                                                                                                                                                                                                     │         1 │      1 │    0.0 │    0.0 │
# │ 9061b312-db18-400c-83e4-2694c37d738e │                63 │ E2E NLG CHALLENGE             │ EVENT   │ The E2E NLG Challenge is a competition focused on evaluating natural language generation models                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  │ [9008a87258d6704755ee05a165b55cb5ae4b3d576e8c6426717913d3ac515534899a936748bada7a93e32caa151dbc8ebf2e4c0a90bab85f718cb29df9667d48]                                                                                                                                                                                                                                                                     │         1 │      1 │    0.0 │    0.0 │
# │ 5fe85cd1-f5ea-4173-95a6-12b8d5d3722c │                64 │ WEBNLG                        │ EVENT   │ WebNLG is a dataset used to evaluate natural language generation models, focusing on generating text from structured data                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        │ [9008a87258d6704755ee05a165b55cb5ae4b3d576e8c6426717913d3ac515534899a936748bada7a93e32caa151dbc8ebf2e4c0a90bab85f718cb29df9667d48]                                                                                                                                                                                                                                                                     │         1 │      2 │    0.0 │    0.0 │
# │ 683b0706-a2d6-44d0-8f3d-de95d849e477 │                65 │ DART                          │ EVENT   │ DART is a dataset used to evaluate natural language generation models, focusing on generating text from structured data                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          │ [9008a87258d6704755ee05a165b55cb5ae4b3d576e8c6426717913d3ac515534899a936748bada7a93e32caa151dbc8ebf2e4c0a90bab85f718cb29df9667d48]                                                                                                                                                                                                                                                                     │         1 │      2 │    0.0 │    0.0 │
# │ fc807444-9384-4c8d-8fb6-f1cd2c477ec6 │                68 │ MNLI-MATCHED                  │ EVENT   │ MNLI-matched is a dataset used for evaluating language models on natural language inference tasks                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                │ [683495fea12abcf4d6f96d49a4f03bd91021735476b2e787a6e482ceb88fa0869c1d8b487dce4c6e3f2b9fbbf3ff69e0bc78684f60bfe4034340ce1d554e57d9]                                                                                                                                                                                                                                                                     │         1 │      1 │    0.0 │    0.0 │
# │ 4c68be42-d7ae-4eeb-bf18-16505b769004 │                89 │ NLP                           │ EVENT   │ NLP, or Natural Language Processing, is a field of study focused on the interaction between computers and human language, and is a critical topic in the context of using pre-trained language models for downstream tasks                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       │ [14542facc7bca54ac03efd874772d9ac87553a713ec6acda8dcbc36eb377443c5121e7e09c7e0add6b25b9e65932e4b1fb46544a980140e966e0d872e1cc16fb]                                                                                                                                                                                                                                                                     │         1 │      1 │    0.0 │    0.0 │
# ├──────────────────────────────────────┴───────────────────┴───────────────────────────────┴─────────┴──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴───────────┴────────┴────────┴────────┤
# │ 16 rows                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    10 columns │
# └───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
