# %% [markdown]
# <a href="https://colab.research.google.com/github/towardsai/ai-tutor-rag-system/blob/main/notebooks/10-Adding_Reranking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Adding Reranking
#
# Every retrieval lesson so far ended on the same itch: the right chunk is usually *in* the results — just not *first*. The more-chunks experiment showed that digging deeper only buries the needle under distractors you then pay to send; hybrid search improved what enters the list more than where things land in it. This notebook adds the component whose entire job is the ordering: a **reranker** that re-reads every shortlisted chunk next to the query and promotes the ones that actually answer it — the same second stage, same model, same constants the production AI Tutor runs.
#
# 📎 *Every pipeline function used here was built by hand in earlier lessons and is re-pasted below in plain Python — `generate()`/`embed()`, `chunk()`/`search()` from Sections 3–4, and the Hybrid Search lesson's BM25 + RRF shortlist — so this notebook runs standalone.*

# %% [markdown]
# ## 🧭 What You'll Learn
#
# - Why the order your retriever returns is a first draft — and why fixing the **order** beats retrieving **more**
# - What a cross-encoder-style reranker actually is, why it out-ranks a bi-encoder, and why it can only afford to read a shortlist
# - Re-assembling the hybrid retriever (dense + BM25 + RRF) as the reranker's **candidate generator**
# - Calling Cohere's `rerank-v4.0-fast` directly through `ClientV2` — with the live AI Tutor's production constants (keep 5, drop scores under 0.10)
# - Evaluating with hit rate and MRR so the reranker is *genuinely inside* the measured loop — and the historical bug that once made this lesson's published numbers measure nothing at all

# %% [markdown]
# ## 1. Setup: Environment, Keys, and Providers
#
# One setup cell installs the pinned SDK profile, loads your keys, and picks the models. The **model fields are editable dropdowns** — choose a listed default or type any newer model ID. (Locally, edit the string.)
#
# New requirement this lesson: a **Cohere key** for the reranker ([free trial keys](https://dashboard.cohere.com/api-keys) are rate-limited but sufficient here), on top of whichever chat/embedding provider keys you selected.

# %%
# ============================================================
# ⚙️ Setup — environment, dependencies, API keys, provider
# ============================================================
import os
import sys

IN_COLAB = "google.colab" in sys.modules

# Pick your model providers (dropdowns in Colab; edit the values locally)
PROVIDER = "gemini"  # @param ["gemini", "openai", "anthropic"]
EMBED_PROVIDER = "gemini"  # @param ["gemini", "openai"]  (Anthropic has no embedding API)

# Pick a model for the selected provider — or TYPE any newer model ID into the
# box (the dropdown is editable thanks to allow-input):
CHAT_MODEL = "gemini-3.7-flash"  # @param ["gemini-3.7-flash", "gpt-5.6-luna", "claude-sonnet-5"] {allow-input: true}
EMBED_MODEL = "gemini-embedding-001"  # @param ["gemini-embedding-001", "text-embedding-3-small"] {allow-input: true}

_KEY_FOR = {"gemini": "GOOGLE_API_KEY", "openai": "OPENAI_API_KEY", "anthropic": "ANTHROPIC_API_KEY"}
# The reranker is a separate vendor: COHERE_API_KEY is required this lesson,
# on top of the chat/embedding keys for the providers picked above.
REQUIRED_KEYS = sorted({_KEY_FOR[PROVIDER], _KEY_FOR[EMBED_PROVIDER]}) + ["COHERE_API_KEY"]

if IN_COLAB:
    import importlib
    import site
    import subprocess

    # Shared install profile, pinned course-wide (July 2026). This lesson's
    # extra: cohere — the reranker's SDK.
    subprocess.run(
        [
            sys.executable, "-m", "pip", "install", "-q", "-U",
            "google-genai==2.3.0",
            "openai==2.46.0",
            "anthropic==0.117.0",
            "chromadb==1.5.9",
            "tiktoken==0.13.0",
            "cohere==7.0.8",
        ],
        check=True,
    )
    importlib.reload(site)  # make newly installed packages importable without a runtime restart

    # In Colab: Secrets tab (🔑 icon) → Add new secret → e.g. COHERE_API_KEY
    from google.colab import userdata

    for key in REQUIRED_KEYS:
        os.environ[key] = userdata.get(key)

if not IN_COLAB:
    get_ipython().run_line_magic("load_ext", "autoreload")
    get_ipython().run_line_magic("autoreload", "2")

    # Locally: dependencies are installed once from the repo's requirements.
    # Keys live in a .env file at the repo root.
    from dotenv import load_dotenv

    load_dotenv()
    missing = [k for k in REQUIRED_KEYS if not os.getenv(k)]
    assert not missing, f"Missing from .env: {missing}"

print(f"✅ Setup complete — {'Colab' if IN_COLAB else 'local'} | chat: {PROVIDER} | embeddings: {EMBED_PROVIDER} | reranker: Cohere")
# Out:
# ✅ Setup complete — local | chat: gemini | embeddings: gemini | reranker: Cohere

# %% [markdown]
# ## 2. The Pipeline, Redefined in Plain Python
#
# Everything this notebook needs, with a 📎 note naming the lesson that built it. Nothing here is new machinery — the new component arrives in Section 6; these cells exist so it has a working pipeline to land in.

# %%
# 📎 generate() and embed() — the two course helpers, exactly as built in
#    "How To Use LLMs via API" and "Basic RAG".
from anthropic import Anthropic
from google import genai
from google.genai import types as genai_types
from openai import OpenAI

# Course-standard default models per provider (August 2026)
MODELS = {
    "gemini": "gemini-3.7-flash",
    "openai": "gpt-5.6-luna",
    "anthropic": "claude-sonnet-5",
}

# The setup-cell form selection (or any typed model ID) overrides the default:
MODELS[PROVIDER] = CHAT_MODEL
EMBED_MODELS = {
    "gemini": "gemini-embedding-001",
    "openai": "text-embedding-3-small",
}
EMBED_MODELS[EMBED_PROVIDER] = EMBED_MODEL  # setup-cell selection (or typed ID) wins
EMBED_DIM = 1536  # placeholder — the prebuilt store's manifest sets the real width below

# Create only the clients we actually need
if "gemini" in (PROVIDER, EMBED_PROVIDER):
    gemini_client = genai.Client()
if "openai" in (PROVIDER, EMBED_PROVIDER):
    openai_client = OpenAI()
if PROVIDER == "anthropic":
    anthropic_client = Anthropic()


def generate(prompt, system=None, model=None):
    """Send one prompt to the selected PROVIDER and return the reply text."""
    if PROVIDER == "gemini":
        response = gemini_client.models.generate_content(
            model=model or MODELS["gemini"],
            contents=prompt,
            config=genai_types.GenerateContentConfig(system_instruction=system),
        )
        return response.text

    if PROVIDER == "openai":
        response = openai_client.responses.create(
            model=model or MODELS["openai"],
            instructions=system,
            input=prompt,
            reasoning={"effort": "none"},
        )
        return response.output_text

    if PROVIDER == "anthropic":
        response = anthropic_client.messages.create(
            model=model or MODELS["anthropic"],
            max_tokens=4096,
            **({"system": system} if system else {}),
            messages=[{"role": "user", "content": prompt}],
        )
        return response.content[0].text

    raise ValueError(f"Unknown PROVIDER: {PROVIDER!r}")


def embed(texts, task="document"):
    """Embed a list of texts with the selected EMBED_PROVIDER.

    Returns a list of EMBED_DIM-dimensional vectors (one per input text).
    task: "document" for corpus chunks, "query" for user questions —
    Gemini embeds the two slightly differently to improve retrieval.
    """
    if isinstance(texts, str):
        texts = [texts]
    # Embedding models work best on single-line inputs
    texts = [t.replace("\n", " ") for t in texts]

    if EMBED_PROVIDER == "gemini":
        result = gemini_client.models.embed_content(
            model=EMBED_MODELS["gemini"],
            contents=texts,
            config=genai_types.EmbedContentConfig(
                task_type="RETRIEVAL_DOCUMENT" if task == "document" else "RETRIEVAL_QUERY",
                output_dimensionality=EMBED_DIM,
            ),
        )
        return [e.values for e in result.embeddings]

    if EMBED_PROVIDER == "openai":
        result = openai_client.embeddings.create(
            model=EMBED_MODELS["openai"], input=texts
        )
        return [d.embedding for d in result.data]

    raise ValueError(f"Unknown EMBED_PROVIDER: {EMBED_PROVIDER!r}")

# %%
# 📎 The pipeline functions, named after the lesson that built each one.
import tiktoken

# — chunk() and n_tokens(): "From Script to Pipeline"
ENC = tiktoken.get_encoding("cl100k_base")


def n_tokens(text):
    """Number of tokens in a string."""
    return len(ENC.encode(text))


def chunk(text, chunk_size=512, chunk_overlap=128):
    """Split text into token-based chunks; consecutive chunks share chunk_overlap tokens."""
    tokens = ENC.encode(text)
    chunks = []
    step = chunk_size - chunk_overlap
    for start in range(0, len(tokens), step):
        window = tokens[start : start + chunk_size]
        chunks.append(ENC.decode(window))
        if start + chunk_size >= len(tokens):
            break  # the final window reached the end of the text
    return chunks


# — search(): "Evaluating Your RAG Pipeline" (returns ids, for the metrics)
def search(query, top_k=5):
    result = collection.query(
        query_embeddings=[embed(query, task="query")[0]], n_results=top_k
    )
    return [
        {"id": cid, "text": doc, "score": 1 - dist, **meta}
        for cid, doc, dist, meta in zip(
            result["ids"][0], result["documents"][0],
            result["distances"][0], result["metadatas"][0],
        )
    ]


def show_chunks(hits, max_chars=120):
    """Print retrieved chunks with scores — look before you measure."""
    for r in hits:
        preview = r["text"][:max_chars].replace("\n", " ")
        print(f"  {r['score']:.4f} | {r['title'][:40]:40} | {preview}…")

# %% [markdown]
# ## 3. The Corpus: the AI-Tutor Knowledge Base — Prebuilt
#
# Rerankers earn their keep when the haystack is deep enough that good chunks routinely land at rank 8 or 15 — so, as in the more-chunks lesson, we use the real `ai_tutor_knowledge` corpus (788 documents of framework and tool documentation (LangChain, LlamaIndex, the OpenAI and Claude Code docs, LangGraph, Deep Agents) plus Agent Engineering course lessons — the production tutor's raw material).
#
# It arrives as a **prebuilt Chroma store**: 788 documents → 7,428 chunks (512-token chunks, 128 overlap — the course defaults), downloaded from the course dataset repo, verified against its `manifest.json`, and opened ready to serve. Only queries are embedded live; the manifest sets `EMBED_DIM` so the query side matches the stored vectors.

# %%
import json
import pathlib
import shutil
import zipfile

import requests

# One prebuilt store per embedding provider — same corpus, same chunking, only
# the embedding configuration differs. Gemini (3072d) is the course default.
STORE_BASE = "https://huggingface.co/datasets/towardsai-tutors/full-stack-ai-engineering-data/resolve/main/vector_stores/"
STORE_FOR = {
    "gemini": "ai_tutor_knowledge-gemini-embedding-001-3072d",
    "openai": "ai_tutor_knowledge-text-embedding-3-small-1536d",
}
DATASET_SHA = "0e801a3f"  # ties each store zip to the exact corpus file it was built from

slug = STORE_FOR[EMBED_PROVIDER]
zip_path = pathlib.Path(f"{slug}-{DATASET_SHA}.zip")
store_dir = pathlib.Path("prebuilt_stores_extracted") / slug

if not zip_path.exists():
    print(f"Downloading {zip_path.name} (~100-150 MB, one time)…")
    with requests.get(STORE_BASE + zip_path.name, stream=True, timeout=600) as response:
        response.raise_for_status()
        with open(zip_path, "wb") as f:
            shutil.copyfileobj(response.raw, f)

# Extract FRESH each run — what we verify below is what the zip contains.
if store_dir.exists():
    shutil.rmtree(store_dir)
store_dir.parent.mkdir(exist_ok=True)
with zipfile.ZipFile(zip_path) as zf:
    zf.extractall(store_dir.parent)

manifest = json.loads((store_dir / "manifest.json").read_text())

import chromadb

chroma_client = chromadb.PersistentClient(path=str(store_dir / "chroma"))
collection = chroma_client.get_collection(manifest["collection_name"])

# Trust, but verify: the manifest is the store's claim, written down.
assert collection.count() == manifest["counts"]["chunks"], "chunk count ≠ manifest"
EMBED_DIM = manifest["dimensions"]["actual"]  # queries must match the stored vectors' width

print(f"Prebuilt store ready: {collection.count():,} chunks from "
      f"{manifest['source_dataset']['documents']} documents | "
      f"{manifest['embedding_model']} @ {EMBED_DIM}d")
# Out:
# Prebuilt store ready: 7,428 chunks from 788 documents | gemini-embedding-001 @ 3072d

# %%
# Always LOOK at retrieval before trying to improve it — this dense-only
# ordering is the first draft the rest of the notebook second-guesses.
hits = search("What is Retrieval-Augmented Generation?", top_k=3)
show_chunks(hits)
# Out:
#   0.8014 | Lesson 9: Retrieval-Augmented Generation |  RAG system. Its primary job is to take a user's query and efficiently find the most relevant information from your know…
#   0.7945 | Lesson 9: Retrieval-Augmented Generation | , and clear instructions for the LLM on how to use that context to generate an accurate answer [[4]](https://towardsai.n…
#   0.7876 | Lesson 9: Retrieval-Augmented Generation | ]](https://decodingml.substack.com/p/rag-fundamentals-first?utm_source=publication-search).  After splitting, we pass ea…

# %% [markdown]
# **What just happened?** The store opened straight from disk and the dense ranker ran against it unchanged — the ordering you just printed is the first draft the reranker will correct. No embedding pass, no new machinery: the interesting work in this lesson happens *after* retrieval.

# %% [markdown]
# ## 4. What a Reranker Actually Is
#
# Everything retrieval has done so far rests on **bi-encoders**: the embedding model read each chunk *alone* — long before any question existed — and froze it into a single vector. Your query got the same treatment, and "relevance" was reduced to geometry between the two compressions. That separateness is precisely what makes vector search fast (documents embed once; queries only meet an index), and precisely why its ranking is a first draft: each chunk was compressed with no idea what you would ask.
#
# A **reranker** is the second draft. It is a **cross-encoder-style model**: it reads the query and one candidate chunk *together* in a single input, lets every token of the question attend to every token of the chunk, and emits one number — how useful this chunk is *for this query*. Nothing was compressed in advance, which is why it catches what embeddings blur: negations, "before" vs "after", version numbers, which entity did what to which.
#
# | | Bi-encoder (embeddings) | Cross-encoder-style reranker |
# |---|---|---|
# | Reads | query and chunk **separately** | query and chunk **together** |
# | Produces | one vector per text, computed once | one relevance score per pair, per query |
# | Cost profile | embed corpus once, then cheap index math | one model pass per candidate, every query |
# | Scales to | millions of chunks | a shortlist of tens |
# | Role | cast a wide net | order the catch |
#
# Neither replaces the other. The reranker is affordable *only because* the fast stage first cuts millions of chunks down to a shortlist — which is why it is always drawn as a second stage, never as the retriever.
#
# One definition worth stating carefully, because earlier editions of this lesson blurred it: a production reranker is **not usually a chat LLM**. Models like Cohere's rerank family are compact, purpose-built scorers — trained on relevance labels to emit a calibrated score, far cheaper and faster than a general chat model, and unable to write you a paragraph. ⏭️ *The previous lesson — where you pressed a general chat LLM into service as a judge that ranked chunks — was the teaching special case: ideal for reading the model's reasoning, wrong tool for a production hot path measured in tens of milliseconds. This lesson is that same idea, industrialized.*

# %% [markdown]
# ## 5. Candidate Generation: the Hybrid Shortlist
#
# The reranker needs something to rerank, and the strongest cheap shortlist we have is the hybrid retriever: dense vectors for meaning, BM25 for exact words, Reciprocal Rank Fusion to merge the two rankings without ever comparing their incomparable scores. The next cell re-pastes that machinery unchanged — 📎 *built in the Hybrid Search lesson* — so this notebook stands alone.
#
# The one **new** decision is the shortlist size, `N_CANDIDATES = 20`: deep enough that the right chunk is almost always *somewhere* in it, small enough that scoring every candidate is one cheap API call. Recall the more-chunks lesson's itch — the gold chunk lurking at rank 7 or 15, where a fixed `top_k=5` never looks. With a reranker downstream, those ranks stop being losses: rank 17 in the shortlist can still finish first.

# %%
# 📎 built in the Hybrid Search lesson — re-pasted unchanged: the minimal
#    tokenizer, the BM25 keyword index, and Reciprocal Rank Fusion.
import math
import re
from collections import Counter


def tokenize(text):
    """Lowercase word tokens — the minimal tokenizer BM25 needs."""
    return re.findall(r"[a-z0-9]+", text.lower())


class BM25Index:
    """Classic BM25 keyword scoring over tokenized chunks (k1=1.5, b=0.75)."""

    def __init__(self, ids, texts, k1=1.5, b=0.75):
        self.ids, self.k1, self.b = ids, k1, b
        self.docs = [tokenize(t) for t in texts]
        self.doc_len = [len(d) for d in self.docs]
        self.avg_len = sum(self.doc_len) / len(self.docs)
        self.tf = [Counter(d) for d in self.docs]
        n = len(self.docs)
        df = Counter(term for doc in self.docs for term in set(doc))
        self.idf = {t: math.log(1 + (n - c + 0.5) / (c + 0.5)) for t, c in df.items()}

    def search(self, query, top_k=10):
        """Score every chunk against the query terms; return (id, score) pairs."""
        scores = Counter()
        for term in tokenize(query):
            if term not in self.idf:
                continue  # the corpus has never seen this word
            for i, tf in enumerate(self.tf):
                if term in tf:
                    freq = tf[term]
                    length_norm = 1 - self.b + self.b * self.doc_len[i] / self.avg_len
                    scores[i] += self.idf[term] * freq * (self.k1 + 1) / (freq + self.k1 * length_norm)
        return [(self.ids[i], score) for i, score in scores.most_common(top_k)]


def rrf_fuse(rankings, k=60):
    """Reciprocal Rank Fusion: positions in, fused scores out — no score mixing."""
    fused = Counter()
    for ranking in rankings:
        for rank, chunk_id in enumerate(ranking):
            fused[chunk_id] += 1 / (k + rank + 1)
    return fused.most_common()

# %%
# The keyword index covers the SAME stored chunks as the vector index —
# one corpus, two views of it.
stored = collection.get(include=["documents", "metadatas"])
bm25 = BM25Index(stored["ids"], stored["documents"])
CHUNKS = {
    cid: {"id": cid, "text": doc, **meta}
    for cid, doc, meta in zip(stored["ids"], stored["documents"], stored["metadatas"])
}

N_CANDIDATES = 20  # shortlist size handed to the reranker


# 📎 The Hybrid Search lesson's retriever, unchanged: dense + BM25 → RRF.
def hybrid_search(query, top_k=N_CANDIDATES):
    dense_ids = [r["id"] for r in search(query, top_k=top_k)]
    keyword_ids = [cid for cid, _ in bm25.search(query, top_k=top_k)]
    fused = rrf_fuse([dense_ids, keyword_ids])[:top_k]
    return [{**CHUNKS[cid], "score": score} for cid, score in fused]


print(f"BM25 index over {len(CHUNKS)} chunks — fused shortlist per query: {N_CANDIDATES}")
# Out:
# BM25 index over 7428 chunks — fused shortlist per query: 20

# %% [markdown]
# **What just happened?** The same chunks now live in two indexes — Chroma holds their vectors, `BM25Index` holds their token statistics — and `hybrid_search()` returns one fused shortlist using the course's fixed fusion constants (BM25 `k1=1.5`, `b=0.75`; RRF `k=60`). Note what the fused "score" is: a sum of reciprocal ranks, not a judgment. RRF knows where each ranker *placed* a chunk and nothing about how useful the chunk actually is. Producing that missing judgment is exactly the job we now delegate.

# %% [markdown]
# ## 6. `rerank()`: Scoring the Shortlist with Cohere
#
# Cohere's rerankers are called through the same `ClientV2` you met in the embedding-model lesson — one method, `rerank`: it takes the query plus the candidate texts and returns them re-ordered, each with a `relevance_score` in [0, 1].
#
# The two constants below are not placeholders — they are the **production constants** the live AI Tutor ships:
#
# - **Keep the top 5** (`RERANK_TOP_N = 5`): enough grounding for generation without re-stuffing the prompt with the distractors we just paid to demote.
# - **Drop anything scoring under 0.10** (`MIN_RELEVANCE = 0.10`): when the corpus simply doesn't contain an answer, an honest near-empty context beats five confident-looking wrong chunks — this floor is what lets the tutor say "I don't know" instead of hallucinating from noise.
#
# One practical wrapper around the call: Cohere's **free trial keys allow 10 rerank calls per minute**, and the evaluation in Section 8 fires one call per question — so `_rerank_call()` catches `TooManyRequestsError` and retries with exponential backoff. That is not lesson scaffolding: rate-limit backoff is what any production client does around a metered API.
#
# The floor deserves the extra sentence: unlike cosine similarities, rerank scores are usefully calibrated *within* one model, so a fixed threshold behaves consistently across queries. They are still **not** comparable across different rerank models — if you ever change `RERANK_MODEL`, re-tune the floor.

# %%
import time

import cohere

cohere_client = cohere.ClientV2()  # reads COHERE_API_KEY from the environment

RERANK_MODEL = "rerank-v4.0-fast"  # what the production AI Tutor runs (July 2026)

# The production constants — the live tutor ships exactly these two numbers:
RERANK_TOP_N = 5      # keep the 5 most useful chunks…
MIN_RELEVANCE = 0.10  # …and drop any "winner" the model itself scores as noise

# Cohere's free trial keys allow only 10 rerank calls per minute, and Section 8
# makes one call per eval question — so a trial key will hit that ceiling mid-run.
# Backing off and retrying is the standard fix (a paid key never enters this path).
MAX_RETRIES = 7  # 1+2+4+…+32s of backoff — more than the 60s window the cap slides over


def _rerank_call(query, documents, top_n):
    """One rerank API call, retried with exponential backoff on rate limits."""
    for attempt in range(MAX_RETRIES):
        try:
            return cohere_client.rerank(
                model=RERANK_MODEL, query=query, documents=documents, top_n=top_n
            )
        except cohere.errors.TooManyRequestsError:
            wait = 2 ** attempt  # 1s, 2s, 4s … until the rate-limit window has moved on
            print(f"  rate limited — waiting {wait}s (attempt {attempt + 1}/{MAX_RETRIES})")
            time.sleep(wait)
    raise RuntimeError(f"rerank still rate limited after {MAX_RETRIES} attempts")


def rerank(query, candidates, top_n=RERANK_TOP_N):
    """Cross-encoder pass: score each (query, candidate) pair, keep the best.

    One API call scores the whole shortlist; results come back sorted by
    relevance_score, which we cut at top_n and at the MIN_RELEVANCE floor.
    """
    response = _rerank_call(query, [c["text"] for c in candidates], top_n)
    kept = []
    for hit in response.results:  # best first
        if hit.relevance_score < MIN_RELEVANCE:
            continue  # below the floor: the model itself calls this one useless
        kept.append({**candidates[hit.index], "score": hit.relevance_score})
    return kept


def rerank_search(query, top_k=5):
    """The full production retrieval pipeline: hybrid shortlist → rerank.

    This one function IS what Section 8 evaluates — there is no optional
    seam where the reranker could silently drop out of the measured path.
    """
    return rerank(query, hybrid_search(query, top_k=N_CANDIDATES), top_n=top_k)

# %% [markdown]
# ## 7. Before and After: One Query, Two Orders
#
# The clearest way to *see* a reranker work is to print the shortlist twice — once in the fused order the reranker received, once in the order it returned. The question below is deliberately chosen from the corpus's agent-tooling half: **MCP** documentation exists under five different sources here (Claude Code, OpenAI, LangChain, LlamaIndex, Deep Agents), so a query about *one* of them has four convincing distractors. That is precisely the situation a reranker exists for.
#
# **Read the two score columns on their own scales.** RRF scores are rank arithmetic, not similarity: each list contributes $1/(60 + \text{rank})$, so a chunk both retrievers put first scores $\frac{1}{61} + \frac{1}{61} \approx 0.0328$ — that is the **ceiling**, not a middling result. A score near $0.03$ is therefore about as good as fusion gets, and a score near $0.0164$ ($\approx 1/61$) marks a chunk **only one** retriever ever saw. Rerank scores are calibrated relevance in $[0, 1]$. Different animals, same chunks — compare within a column, never across.

# %%
QUESTION = "How do I give a Deep Agent access to MCP tools?"

candidates = hybrid_search(QUESTION, top_k=N_CANDIDATES)
reranked = rerank(QUESTION, candidates)

print(f"─── BEFORE · fused hybrid order (top 5 of {len(candidates)} candidates | RRF scores) ───")
show_chunks(candidates[:5])

print(f"\n─── AFTER · reranked order (top {len(reranked)} kept | relevance scores) ───")
show_chunks(reranked)

# The reranker's fingerprint: where each kept chunk SAT in the fused shortlist.
fused_rank = {c["id"]: i + 1 for i, c in enumerate(candidates)}
print("\nfused-list position of each kept chunk:", [fused_rank[r["id"]] for r in reranked])
# Out:
# ─── BEFORE · fused hybrid order (top 5 of 20 candidates | RRF scores) ───
#   0.0284 | Connect to external tools with MCP       |  becomes `mcp__github__list_issues`.  ### Auto-approve with allowedTools  Use `allowedTools` to auto-approve specific MC…
#   0.0258 | Building MCP servers for ChatGPT Apps an |  ChatGPT supplies during the interaction, potentially including sensitive data the user may earlier have provided to Cha…
#   0.0164 | MCP tools                                | --- title: MCP tools sidebarTitle: MCP tools description: Load additional tools from MCP (Model Context Protocol) server…
#   0.0164 | Deep research                            |  via the [web search tool](https://developers.openai.com/api/docs/guides/tools-web-search). To give the model access to …
#   0.0161 | MCP tools                                |  to project-level trust gating). Pass `--config <path>` to use a specific file:  ```bash deepagents mcp login linear --c…
#
# ...

# %% [markdown]
# **What just happened?** (Run it — the cell is left unexecuted, and your output will differ.) Expect three things. Chunks that merely *mention* the query's words slide down; chunks that actually *answer* climb, often from well below the old cutoff. The final line is the part to stare at: it lists where each surviving chunk sat in the fused order — something like `[3, 1, 9, 2, 14]` means two of your five context slots were rescued from ranks a `top_k=5` retriever would never have shown the LLM. And if that line reads `[1, 2, 3, 4, 5]` query after query, be suspicious: either fusion was already perfect (rare on a 20-deep shortlist) or your reranker is not actually in the loop — which, as the next section shows, is not a hypothetical failure mode.

# %% [markdown]
# ## 8. Evaluate It — with the Reranker Inside the Loop
#
# Same yardstick as every retrieval lesson: 📎 *`make_qa_pairs()`, hit rate, and MRR from "Evaluating Your RAG Pipeline", verbatim* — questions generated from stored chunks, each carrying its gold `chunk_id`, saved to JSON so a rerun reloads instead of re-generating (and re-paying).
#
# The design decision that matters: the thing being scored is **`rerank_search()` itself** — the same function you would ship. Every eval question therefore triggers real candidate generation *and* a real rerank API call: ~25 questions ≈ cents on a paid key (a free trial key covers it too, just slower under its rate cap). Three retrievers, one table — each judged on exactly what it would put into the prompt at `top_k=5`.

# %%
from pathlib import Path

# 📎 make_qa_pairs() from "Evaluating Your RAG Pipeline" — verbatim.
QA_GEN_PROMPT = """Context information is below.
---------------------
{context}
---------------------
Given ONLY the context above and no prior knowledge, write {n} quiz question(s)
that this context can answer on its own. Questions must be self-contained.

Return ONLY a JSON array of question strings, e.g. ["What is X?"]"""


def _parse_json(raw):
    return json.loads(raw.strip().removeprefix("```json").removeprefix("```").removesuffix("```").strip())


def make_qa_pairs(collection, n_chunks=25, questions_per_chunk=1):
    """Generate (question, gold chunk_id) pairs from a sample of stored chunks."""
    sample = collection.get(limit=n_chunks, include=["documents"])
    qa_pairs = []
    for chunk_id, text in zip(sample["ids"], sample["documents"]):
        raw = generate(QA_GEN_PROMPT.format(context=text, n=questions_per_chunk))
        try:
            questions = _parse_json(raw)
        except json.JSONDecodeError:
            continue
        for q in questions[:questions_per_chunk]:
            qa_pairs.append({"question": q, "chunk_id": chunk_id})
    return qa_pairs


# ⚠️ Gold ids must come from THIS corpus and THIS chunking — the filename is
# lesson-specific so another notebook's saved eval set can't sneak in.
EVAL_PATH = Path("rerank_eval_dataset.json")

if EVAL_PATH.exists():
    qa_pairs = json.loads(EVAL_PATH.read_text())  # reload instead of re-generating (and re-paying)
    print(f"Loaded {len(qa_pairs)} question–chunk pairs from {EVAL_PATH}")
else:
    qa_pairs = make_qa_pairs(collection, n_chunks=25, questions_per_chunk=1)
    EVAL_PATH.write_text(json.dumps(qa_pairs, indent=2))
    print(f"Generated and saved {len(qa_pairs)} question–chunk pairs to {EVAL_PATH}")
# Out:
# Loaded 25 question–chunk pairs from rerank_eval_dataset.json

# %%
import pandas as pd


# 📎 Hit rate and MRR from "Evaluating Your RAG Pipeline", folded into one
#    evaluator that takes ANY (query, top_k) -> hits callable.
def evaluate_retrieval(qa_pairs, search_fn, top_k=5):
    """Hit rate + MRR for one retriever over the eval set."""
    hits = 0
    rr_total = 0.0
    for pair in qa_pairs:
        ids = [r["id"] for r in search_fn(pair["question"], top_k)]
        if pair["chunk_id"] in ids:
            hits += 1
            rr_total += 1 / (ids.index(pair["chunk_id"]) + 1)
    n = len(qa_pairs)
    return {"hit_rate": hits / n, "mrr": rr_total / n, "queries": n, "top_k": top_k}


# Three pipelines, judged on what each would actually hand the LLM.
# rerank_search runs the REAL reranker on every question — by construction,
# these numbers cannot be produced without it.
RETRIEVERS = {
    "vector only": lambda q, k: search(q, top_k=k),
    "hybrid (fused, no rerank)": lambda q, k: hybrid_search(q, top_k=k),
    "hybrid + rerank": lambda q, k: rerank_search(q, top_k=k),
}

rows = [
    {"retriever": name, **evaluate_retrieval(qa_pairs, search_fn=fn, top_k=5)}
    for name, fn in RETRIEVERS.items()
]
pd.DataFrame(rows)
# Out:
#   rate limited — waiting 1s (attempt 1/7)
#   rate limited — waiting 1s (attempt 1/7)
#   rate limited — waiting 1s (attempt 1/7)
#   rate limited — waiting 2s (attempt 2/7)
#                    retriever  hit_rate       mrr  queries  top_k
# 0                vector only      0.72  0.470000       25      5
# 1  hybrid (fused, no rerank)      0.96  0.734667       25      5
# 2            hybrid + rerank      1.00  0.900000       25      5

# %% [markdown]
# **What just happened?** The cells above are left unexecuted — run them and read your table like this. The **hybrid** row can beat **vector only** on hit rate (that was the hybrid lesson's result). The **hybrid + rerank** row can beat both, and for two distinct reasons: it *chooses from deeper* — its five slots are filled from a 20-candidate shortlist, so anything rescued from ranks 6–20 is recall the fixed-k rows never had — and it *orders better*, which is what **MRR** measures. MRR is the reranker's honest scoreboard: its job was never to find more, it is to put the right chunk **first**, and rank 1 versus rank 4 is the difference between an answer grounded in the top of the prompt and one fishing below it. If your reranked MRR is *not* clearly above the fused MRR, treat it as an alarm — check that the `MIN_RELEVANCE` floor isn't emptying your lists, and re-read the historical note above.

# %% [markdown]
# ## 🔑 Key Takeaways
#
# - Retrieval is two problems wearing one name: **casting a wide net** (bi-encoders, BM25 — fast, indexable, coarse) and **ordering the catch** (cross-encoders — per-pair, slow, precise). A reranker is affordable only because the first stage hands it a shortlist.
# - A reranker reads query and chunk **together** — the joint attention bi-encoders trade away for speed. It is usually a compact purpose-built scorer, **not a chat LLM**; the previous lesson's LLM-as-judge was the readable special case, not the production pattern.
# - The production shape: hybrid shortlist of **20 candidates** → `rerank()` → keep **top 5**, drop scores under **0.10**. The floor is a calibrated within-model threshold — it is what lets a pipeline say "nothing relevant" instead of hallucinating from noise; re-tune it whenever `RERANK_MODEL` changes.
# - Reranking converts depth into precision: rank 17 in the shortlist can finish at rank 1, so candidates the old `top_k=5` never surfaced become usable recall — without paying the more-chunks lesson's token bill.
# - **Evaluate the function you ship.** `rerank_search()` is simultaneously the production entry point and the thing the eval scores; a component that *can* silently drop out of the measured path eventually will — that is how the pre-port edition published a reranking table with no reranking in it.
# - MRR is the reranker's scoreboard: not "did we find it," but "is it **first**."
# - ⏭️ Reranking perfects the ordering of what you retrieved; the next lever is *what you ask* — transforming the query itself before retrieval ever runs.
