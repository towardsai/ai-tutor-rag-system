# %% [markdown]
# <a href="https://colab.research.google.com/github/towardsai/ai-tutor-rag-system/blob/main/notebooks/Metadata_Filtering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Search With Metadata Filtering
#
# Vector search, as we have built it so far, answers one question: *which chunks are nearest?* Production systems ask a harsher one: *which chunks are nearest **among the ones this query is allowed to touch**?* Only the sources the user ticked in a picker. Only documents this account may read. Only material newer than last quarter. That extra clause is **metadata filtering**, and in Chroma it is one keyword argument: `where=`.
#
# This notebook indexes the full AI-Tutor knowledge base and puts that argument to work — the exact filter shapes the production tutor's source picker sends, the wider operator toolbox behind them, and the characteristic way retrieval fails when a filter excludes the documents that actually hold the answer.
#
# 📎 *Every pipeline function used here was built by hand in earlier lessons and is re-pasted below in plain Python. `search()` already grew its `where=` parameter in the vector-database lesson; this notebook is about everything that parameter can do.*

# %% [markdown]
# ## 🧭 What You'll Learn
#
# - Why "nearest chunks" is not enough in production: retrieval that respects **sources, permissions, and dates**
# - Chroma `where` filters as **hard constraints applied before similarity ranking** — not post-hoc pruning
# - The **literal production filter shapes**: `{"source": ...}` (an `$eq` in disguise) for one selected source, `{"source": {"$in": [...]}}` for several — the tutor app's source picker on the wire
# - The rest of the operator toolbox: `$ne`, comparisons like `$gte` on numeric metadata, and `$and`/`$or` composition
# - The failure mode: a filter that excludes the right documents makes retrieval **confidently wrong** — and how to recognize it

# %% [markdown]
# ## 1. Setup: Environment, Keys, and Providers
#
# One setup cell installs the pinned SDK profile, loads your keys, and picks the models. The **model fields are editable dropdowns** — choose a listed default or type any newer model ID. (Locally, edit the string.)

# %%
# ============================================================
# ⚙️ Setup — environment, dependencies, API keys, provider
# ============================================================
import os
import sys

IN_COLAB = "google.colab" in sys.modules

# Pick your model providers (dropdowns in Colab; edit the values locally)
PROVIDER = "gemini"  # @param ["gemini", "openai", "anthropic"]
EMBED_PROVIDER = "gemini"  # @param ["gemini", "openai"]  (Anthropic has no embedding API)

# Pick a model for the selected provider — or TYPE any newer model ID into the
# box (the dropdown is editable thanks to allow-input):
CHAT_MODEL = "gemini-3.7-flash"  # @param ["gemini-3.7-flash", "gpt-5.6-luna", "claude-sonnet-5"] {allow-input: true}
EMBED_MODEL = "gemini-embedding-001"  # @param ["gemini-embedding-001", "text-embedding-3-small"] {allow-input: true}

_KEY_FOR = {"gemini": "GOOGLE_API_KEY", "openai": "OPENAI_API_KEY", "anthropic": "ANTHROPIC_API_KEY"}
REQUIRED_KEYS = sorted({_KEY_FOR[PROVIDER], _KEY_FOR[EMBED_PROVIDER]})

if IN_COLAB:
    import importlib
    import site
    import subprocess

    # Shared install profile, pinned course-wide (July 2026).
    subprocess.run(
        [
            sys.executable, "-m", "pip", "install", "-q", "-U",
            "google-genai==2.3.0",
            "openai==2.46.0",
            "anthropic==0.117.0",
            "chromadb==1.5.9",
            "tiktoken==0.13.0",
        ],
        check=True,
    )
    importlib.reload(site)  # make newly installed packages importable without a runtime restart

    # In Colab: Secrets tab (🔑 icon) → Add new secret → e.g. GOOGLE_API_KEY
    from google.colab import userdata

    for key in REQUIRED_KEYS:
        os.environ[key] = userdata.get(key)

if not IN_COLAB:
    get_ipython().run_line_magic("load_ext", "autoreload")
    get_ipython().run_line_magic("autoreload", "2")

    # Locally: dependencies are installed once from the repo's requirements.
    # Keys live in a .env file at the repo root.
    from dotenv import load_dotenv

    load_dotenv()
    missing = [k for k in REQUIRED_KEYS if not os.getenv(k)]
    assert not missing, f"Missing from .env: {missing}"

print(f"✅ Setup complete — {'Colab' if IN_COLAB else 'local'} | chat: {PROVIDER} | embeddings: {EMBED_PROVIDER}")
# Out:
# ✅ Setup complete — local | chat: gemini | embeddings: gemini

# %% [markdown]
# ## 2. The Pipeline, Redefined in Plain Python
#
# Everything this notebook needs, with a 📎 note naming the lesson that built it. Nothing here is new machinery — the one line that matters for this lesson is `search()`'s `where=None` parameter, which passes a metadata filter straight through to `collection.query()`.

# %%
# 📎 generate() and embed() — the two course helpers, exactly as built in
#    "How To Use LLMs via API" and "Basic RAG".
from anthropic import Anthropic
from google import genai
from google.genai import types as genai_types
from openai import OpenAI

# Course-standard default models per provider (August 2026)
MODELS = {
    "gemini": "gemini-3.7-flash",
    "openai": "gpt-5.6-luna",
    "anthropic": "claude-sonnet-5",
}

# The setup-cell form selection (or any typed model ID) overrides the default:
MODELS[PROVIDER] = CHAT_MODEL
EMBED_MODELS = {
    "gemini": "gemini-embedding-001",
    "openai": "text-embedding-3-small",
}
EMBED_MODELS[EMBED_PROVIDER] = EMBED_MODEL  # setup-cell selection (or typed ID) wins
EMBED_DIM = 1536  # placeholder — the prebuilt store's manifest sets the real width below

# Create only the clients we actually need
if "gemini" in (PROVIDER, EMBED_PROVIDER):
    gemini_client = genai.Client()
if "openai" in (PROVIDER, EMBED_PROVIDER):
    openai_client = OpenAI()
if PROVIDER == "anthropic":
    anthropic_client = Anthropic()


def generate(prompt, system=None, model=None):
    """Send one prompt to the selected PROVIDER and return the reply text."""
    if PROVIDER == "gemini":
        response = gemini_client.models.generate_content(
            model=model or MODELS["gemini"],
            contents=prompt,
            config=genai_types.GenerateContentConfig(system_instruction=system),
        )
        return response.text

    if PROVIDER == "openai":
        response = openai_client.responses.create(
            model=model or MODELS["openai"],
            instructions=system,
            input=prompt,
            reasoning={"effort": "none"},
        )
        return response.output_text

    if PROVIDER == "anthropic":
        response = anthropic_client.messages.create(
            model=model or MODELS["anthropic"],
            max_tokens=4096,
            **({"system": system} if system else {}),
            messages=[{"role": "user", "content": prompt}],
        )
        return response.content[0].text

    raise ValueError(f"Unknown PROVIDER: {PROVIDER!r}")


def embed(texts, task="document"):
    """Embed a list of texts with the selected EMBED_PROVIDER.

    Returns a list of EMBED_DIM-dimensional vectors (one per input text).
    task: "document" for corpus chunks, "query" for user questions —
    Gemini embeds the two slightly differently to improve retrieval.
    """
    if isinstance(texts, str):
        texts = [texts]
    # Embedding models work best on single-line inputs
    texts = [t.replace("\n", " ") for t in texts]

    if EMBED_PROVIDER == "gemini":
        result = gemini_client.models.embed_content(
            model=EMBED_MODELS["gemini"],
            contents=texts,
            config=genai_types.EmbedContentConfig(
                task_type="RETRIEVAL_DOCUMENT" if task == "document" else "RETRIEVAL_QUERY",
                output_dimensionality=EMBED_DIM,
            ),
        )
        return [e.values for e in result.embeddings]

    if EMBED_PROVIDER == "openai":
        result = openai_client.embeddings.create(
            model=EMBED_MODELS["openai"], input=texts
        )
        return [d.embedding for d in result.data]

    raise ValueError(f"Unknown EMBED_PROVIDER: {EMBED_PROVIDER!r}")

# %%
# 📎 The pipeline functions, named after the lesson that built each one.
import tiktoken

# — chunk() and n_tokens(): "From Script to Pipeline"
ENC = tiktoken.get_encoding("cl100k_base")


def n_tokens(text):
    """Number of tokens in a string."""
    return len(ENC.encode(text))


def chunk(text, chunk_size=512, chunk_overlap=128):
    """Split text into token-based chunks; consecutive chunks share chunk_overlap tokens."""
    tokens = ENC.encode(text)
    chunks = []
    step = chunk_size - chunk_overlap
    for start in range(0, len(tokens), step):
        window = tokens[start : start + chunk_size]
        chunks.append(ENC.decode(window))
        if start + chunk_size >= len(tokens):
            break  # the final window reached the end of the text
    return chunks


# — search(): the vector-database lesson, verbatim — including the where=
#   parameter that this whole notebook is about.
def search(query, top_k=5, where=None):
    """Return the top_k most relevant chunks: text, score, metadata.

    where: optional Chroma metadata filter, e.g. {"source": "claude_code_docs"}.
    """
    result = collection.query(
        query_embeddings=[embed(query, task="query")[0]],
        n_results=top_k,
        where=where,
    )
    return [
        {"text": doc, "score": 1 - dist, **meta}
        for doc, dist, meta in zip(
            result["documents"][0], result["distances"][0], result["metadatas"][0]
        )
    ]


# — show_chunks(): the top-k lesson, with one tweak — it now prints the
#   source column, because source is the field we filter on.
def show_chunks(hits, max_chars=90):
    """Print retrieved chunks with scores — look before you measure."""
    for r in hits:
        preview = r["text"][:max_chars].replace("\n", " ")
        print(f"  {r['score']:.4f} | {r['source']:<12} | {r['title'][:36]:36} | {preview}…")


# — the course RAG prompt and answer(): "From Script to Pipeline", with the
#   where= passthrough added in the vector-database lesson.
SYSTEM_INSTRUCTION = (
    "You are an assistant and expert in answering questions from a chunks of content. "
    "Only answer AI-related question, else say that you cannot answer this question."
)

PROMPT_TEMPLATE = (
    "Read the following informations that might contain the context you require to "
    "answer the question. You can use the informations starting from the "
    "<START_OF_CONTEXT> tag and end with the <END_OF_CONTEXT> tag. Here is the content:\n\n"
    "<START_OF_CONTEXT>\n{context}\n<END_OF_CONTEXT>\n\n"
    "Please provide an informative and accurate answer to the following question based "
    "on the available context. Be concise and take your time.\nQuestion: {question}\nAnswer:"
)


def answer(question, top_k=5, where=None):
    """The whole pipeline in one call: filtered search, then grounded generation."""
    retrieved = search(question, top_k=top_k, where=where)
    context = "\n\n".join(r["text"] for r in retrieved)
    reply = generate(
        PROMPT_TEMPLATE.format(context=context, question=question),
        system=SYSTEM_INSTRUCTION,
    )
    return reply, retrieved

# %% [markdown]
# ## 3. The Corpus — and the Metadata We'll Filter On
#
# Filtering is only interesting when the metadata has variety, so this lesson works with the **full** `ai_tutor_knowledge` corpus — all 788 documents of it: framework and tool documentation (LangChain, LlamaIndex, the OpenAI and Claude Code docs, LangGraph, Deep Agents) plus Agent Engineering course lessons — the production tutor's raw material. An earlier version of this notebook sliced the list as `ai_tutor_knowledge[:100] + ai_tutor_knowledge[500:]` — an innocuous-looking line that silently dropped four hundred documents. No slice this time: what we download is what we filter on.
#
# We still download the raw JSONL — not to embed it (the course's **prebuilt Chroma store** carries the vectors), but because it holds one field this lesson needs and the store doesn't carry: each document's `tokens` count, our numeric filter target.

# %%
import json
import pathlib

import requests

# Course dataset — hosted in the Towards AI org dataset repo on Hugging Face
DATA_URL = "https://huggingface.co/datasets/towardsai-tutors/full-stack-ai-engineering-data/resolve/main/ai_tutor_knowledge.jsonl"
DATA_PATH = pathlib.Path("ai_tutor_knowledge.jsonl")

if not DATA_PATH.exists():
    DATA_PATH.write_bytes(requests.get(DATA_URL, timeout=180).content)
    print("Downloaded", DATA_PATH)

with open(DATA_PATH, encoding="utf-8") as f:
    ai_tutor_knowledge = [json.loads(line) for line in f]

docs = ai_tutor_knowledge  # the FULL corpus — no slicing

print(f"{len(docs)} documents in the corpus — filtering across all of them")
print("\nOne document (fields):")
print({k: str(v)[:60] for k, v in docs[0].items()})
# Out:
# Downloaded ai_tutor_knowledge.jsonl
# 788 documents in the corpus — filtering across all of them
#
# One document (fields):
# {'tokens': '7952', 'doc_id': '54c3f646-d20c-56db-8cd8-b7fcf4058848', 'name': 'Lesson 18: The Research Loop: Query Generation, Perplexity, ', 'url': 'https://academy.towardsai.net/courses/take/agent-engineering', 'source': 'agentic_ai_engineering', 'content': '# Lesson 18: The Research Loop: Query Generation, Perplexity'}

# %%
from collections import Counter

# Look at the metadata BEFORE filtering on it: which source values exist,
# and how are document lengths distributed?
source_counts = Counter(doc["source"] for doc in docs)
print("source values:", dict(source_counts.most_common()))

lengths = sorted(doc["tokens"] for doc in docs)
print(f"tokens per document: min={lengths[0]:,} | median={lengths[len(lengths) // 2]:,} | max={lengths[-1]:,}")
# Out:
# source values: {'langchain': 221, 'llama_index': 206, 'openai_docs': 155, 'claude_code_docs': 100, 'langgraph': 39, 'deep_agents': 37, 'agentic_ai_engineering': 30}
# tokens per document: min=112 | median=1,990 | max=36,463

# %% [markdown]
# ## 4. Load the Prebuilt Store — Then Enrich Its Metadata
#
# 📎 *The vectors come from the course's prebuilt Chroma store — 788 documents → 7,428 chunks (512-token chunks, 128 overlap; built offline by the same `ingest()` loop you wrote in the vector-database lesson). We download the store matching the setup cell's `EMBED_PROVIDER`, verify it against its `manifest.json`, and set `EMBED_DIM` from the manifest so query embedding always matches the stored vectors.*
#
# The store's chunks carry `title`, `url`, and `source` — but not the document's `tokens` count. So this lesson adds it, with `collection.update()`: **metadata is cheap to change; vectors are the expensive part.** Enriching a prebuilt store beats rebuilding it — the update rewrites only the metadata sitting beside each vector, and no embedding API is called at all. The attach-at-write rule still applies, just one step later: only what is in the metadata *before* you query is filterable at query time.

# %%
import json
import pathlib
import shutil
import zipfile

import requests

# One prebuilt store per embedding provider — same corpus, same chunking, only
# the embedding configuration differs. Gemini (3072d) is the course default.
STORE_BASE = "https://huggingface.co/datasets/towardsai-tutors/full-stack-ai-engineering-data/resolve/main/vector_stores/"
STORE_FOR = {
    "gemini": "ai_tutor_knowledge-gemini-embedding-001-3072d",
    "openai": "ai_tutor_knowledge-text-embedding-3-small-1536d",
}
DATASET_SHA = "0e801a3f"  # ties each store zip to the exact corpus file it was built from

slug = STORE_FOR[EMBED_PROVIDER]
zip_path = pathlib.Path(f"{slug}-{DATASET_SHA}.zip")
store_dir = pathlib.Path("prebuilt_stores_extracted") / slug

if not zip_path.exists():
    print(f"Downloading {zip_path.name} (~100-150 MB, one time)…")
    with requests.get(STORE_BASE + zip_path.name, stream=True, timeout=600) as response:
        response.raise_for_status()
        with open(zip_path, "wb") as f:
            shutil.copyfileobj(response.raw, f)

# Extract FRESH each run — what we verify below is what the zip contains.
if store_dir.exists():
    shutil.rmtree(store_dir)
store_dir.parent.mkdir(exist_ok=True)
with zipfile.ZipFile(zip_path) as zf:
    zf.extractall(store_dir.parent)

manifest = json.loads((store_dir / "manifest.json").read_text())

import chromadb

chroma_client = chromadb.PersistentClient(path=str(store_dir / "chroma"))
collection = chroma_client.get_collection(manifest["collection_name"])

# Trust, but verify: the manifest is the store's claim, written down.
assert collection.count() == manifest["counts"]["chunks"], "chunk count ≠ manifest"
EMBED_DIM = manifest["dimensions"]["actual"]  # queries must match the stored vectors' width

print(f"Prebuilt store ready: {collection.count():,} chunks from "
      f"{manifest['source_dataset']['documents']} documents | "
      f"{manifest['embedding_model']} @ {EMBED_DIM}d")
# Out:
# Prebuilt store ready: 7,428 chunks from 788 documents | gemini-embedding-001 @ 3072d

# %%
# The store ships {title, url, source} on every chunk — attach `tokens` now.
# collection.update() rewrites ONLY metadata: no re-embedding, no API calls.
tokens_by_doc = {doc["doc_id"]: doc["tokens"] for doc in docs}

all_ids = collection.get(include=[])["ids"]
BATCH = 5000
for start in range(0, len(all_ids), BATCH):
    batch_ids = all_ids[start : start + BATCH]
    metas = collection.get(ids=batch_ids, include=["metadatas"])["metadatas"]
    for cid, meta in zip(batch_ids, metas):
        meta["tokens"] = tokens_by_doc[cid.rsplit("-", 1)[0]]  # chunk id = {doc_id}-{i}
    collection.update(ids=batch_ids, metadatas=metas)

print(f"Enriched {len(all_ids):,} chunks with their document's `tokens` count")
# Out:
# Enriched 7,428 chunks with their document's `tokens` count

# %%
# One stored item, in full — the metadata sits right next to the vector.
sample = collection.peek(limit=1)
print("id:      ", sample["ids"][0])
print("metadata:", sample["metadatas"][0])
print("document:", sample["documents"][0][:120].replace("\n", " "), "…")

# And a plain, unfiltered search as the baseline — the whole corpus competes.
print("\nUnfiltered top 3:")
show_chunks(search("Explain how advanced RAG variants improve on basic RAG.", top_k=3))
# Out:
# id:       54c3f646-d20c-56db-8cd8-b7fcf4058848-0
# metadata: {'source': 'agentic_ai_engineering', 'tokens': 7952, 'title': 'Lesson 18: The Research Loop: Query Generation, Perplexity, and Human Feedback', 'url': 'https://academy.towardsai.net/courses/take/agent-engineering/multimedia/70289117-lesson-18-the-research-loop-query-generation-perplexity-and-human-feedback'}
# document: # Lesson 18: The Research Loop: Query Generation, Perplexity, and Human Feedback  In this lesson, we will explore the re …
#
# Unfiltered top 3:
#   0.7801 | agentic_ai_engineering | Lesson 9: Retrieval-Augmented Genera |  the context [[9]](https://www.pinecone.io/learn/series/rag/rerankers/). Because a cross-e…
#   0.7562 | agentic_ai_engineering | Lesson 9: Retrieval-Augmented Genera | 1).png)  *Figure 3: The end-to-end RAG pipeline, split into its offline ingestion and onli…
# ...

# %% [markdown]
# **What just happened?** The prebuilt store opened straight from disk, and one `collection.update()` pass later every chunk sits in Chroma with `title`, `url`, `source`, and `tokens` beside its vector — no embedding call anywhere. That metadata has been along for the ride since Section 4 of the course; this is the lesson where it stops being luggage and starts steering retrieval.

# %% [markdown]
# ## 5. Why Metadata Filtering?
#
# Similarity search has no opinions about *provenance* or *permission* — it will happily surface the nearest chunk from a source the user explicitly deselected, a document they are not allowed to read, or a guide that was deprecated last year. Three production requirements that pure similarity cannot express:
#
# 1. **Source scoping** — the production tutor's source picker: the user ticks which document collections a question may search, and the app turns that selection into a `where` filter. This notebook builds that exact feature.
# 2. **Permissions** — retrieval must never surface documents this user cannot read. In a RAG system the retriever *is* the access-control layer: whatever it returns goes into the prompt.
# 3. **Freshness** — "only documentation newer than version X" is a metadata comparison, not a similarity judgment.
#
# All three are the same mechanism: a predicate over metadata, evaluated **before** similarity ranking, deciding which chunks are candidates at all. That ordering matters — filtering *inside* the query is not the same as retrieving `top_k` and dropping offenders afterwards. Post-hoc pruning can leave you with three chunks when you asked for five, or none at all, because disallowed chunks consumed the candidate budget. A `where` filter spends the whole budget on eligible chunks.

# %% [markdown]
# ## 6. Filtering by Source: the Literal Production Shapes
#
# Chroma's `where` argument is a dict. The two shapes below are not textbook examples — they are, byte for byte, what the production tutor's `build_where_filter()` (in the app's `chroma_rag` module) sends to Chroma when a user ticks sources in the picker:
#
# - **One source selected** → `{"source": "claude_code_docs"}` — the shorthand form; Chroma treats it as `{"source": {"$eq": "claude_code_docs"}}`.
# - **Several selected** → `{"source": {"$in": [...]}}` — membership in a list.
#
# Same question every time, so the filter is the only variable.

# %%
QUESTION = "How do I create and use hooks in Claude Code?"

print("— unfiltered: every source competes " + "—" * 34)
show_chunks(search(QUESTION, top_k=3))

# ONE source selected in the picker → plain equality.
WHERE_ONE = {"source": "claude_code_docs"}  # Chroma reads this as {"source": {"$eq": "claude_code_docs"}}
print(f"\n— where={WHERE_ONE} " + "—" * 26)
show_chunks(search(QUESTION, top_k=3, where=WHERE_ONE))
# Out:
# — unfiltered: every source competes ——————————————————————————————————
#   0.8080 | claude_code_docs | Automate workflows with hooks        | > ## Documentation Index > Fetch the complete documentation index at: https://code.claude.…
#   0.8033 | claude_code_docs | Hooks reference                      | > ## Documentation Index > Fetch the complete documentation index at: https://code.claude.…
#   0.8010 | claude_code_docs | Hooks reference                      |  [               {                 "type": "command",                 "command": "${CLAUDE…
#
# — where={'source': 'claude_code_docs'} ——————————————————————————
#   0.8080 | claude_code_docs | Automate workflows with hooks        | > ## Documentation Index > Fetch the complete documentation index at: https://code.claude.…
#   0.8033 | claude_code_docs | Hooks reference                      | > ## Documentation Index > Fetch the complete documentation index at: https://code.claude.…
# ...

# %%
# SEVERAL sources selected in the picker → $in (membership in a list).
# We take the two most common source values counted in Section 3:
SELECTED_SOURCES = [s for s, _ in source_counts.most_common(2)]
WHERE_MANY = {"source": {"$in": SELECTED_SOURCES}}
print("where =", WHERE_MANY, "\n")
show_chunks(search(QUESTION, top_k=3, where=WHERE_MANY))


# The production tutor builds its filter exactly this way — the shape of
# build_where_filter() in the app's chroma_rag module:
def build_where_filter(selected_sources):
    if not selected_sources:
        return None  # nothing selected → search everything
    if len(selected_sources) == 1:
        return {"source": {"$eq": selected_sources[0]}}  # one source → $eq
    return {"source": {"$in": list(selected_sources)}}  # several → $in


for selection in [[], ["claude_code_docs"], SELECTED_SOURCES]:
    print(f"{selection!r:>28} → {build_where_filter(selection)}")
# Out:
# where = {'source': {'$in': ['langchain', 'llama_index']}}
#   0.7140 | langchain    | Custom middleware                    | --- title: Custom middleware ---  import MiddlewareDynamicPromptDecoratorPy from '/snippet…
#   0.7063 | langchain    | LangChain v1 migration guide         | (user_role="expert") ) ``` </CodeGroup>   ### Pre-model hook  Pre-model hooks are now impl…
#   0.7052 | langchain    | ChatAnthropic integration            | ["messages"]:             message.pretty_print()         ```     </Tab>      <Tab title="D…
#                           [] → None
#         ['claude_code_docs'] → {'source': {'$eq': 'claude_code_docs'}}
# ['langchain', 'llama_index'] → {'source': {'$in': ['langchain', 'llama_index']}}

# %% [markdown]
# **What just happened?** The unfiltered block let every source compete; the `$eq` block admitted only `claude_code_docs` chunks; the `$in` block widened eligibility to exactly the listed sources (**your rankings will differ** with corpus version and embedder). Note what did *not* change: the query, the embeddings, `top_k`, the scoring. A `where` filter never re-ranks — it decides who is allowed into the race, then similarity runs the race as usual. And `build_where_filter()` is the entire bridge between a row of checkboxes in the tutor's UI and the retrieval you just ran: empty selection → `None` (search everything), one tick → the `$eq` shape, several ticks → the `$in` shape.

# %% [markdown]
# ## 7. Beyond Equality: Comparisons and Combinations
#
# Equality and membership cover the source picker, but the operator toolbox is wider — and it works on numbers as well as strings:
#
# - **Equality / inequality:** `$eq`, `$ne`
# - **Comparisons** (numeric metadata): `$gt`, `$gte`, `$lt`, `$lte`
# - **Membership:** `$in`, `$nin`
# - **Composition:** `$and`, `$or` over lists of clauses
#
# Our chunks carry a numeric field: `tokens`, the *source document's* total length. So "only chunks from LangChain docs 2,000+ tokens long" — a crude but real proxy for the in-depth guides — is one `$and` away. In a corpus that stores publication dates as numbers, the identical shape gives you "only material newer than X".
#
# *(Every serious vector store ships this same feature under a different name — Qdrant calls these payload filters, pgvector spells them as SQL `WHERE` clauses — the shapes change, the idea doesn't.)*

# %%
# $and combines clauses; $gte compares numbers.
# Reads as: "chunks whose document is a LangChain doc AND 2,000+ tokens long".
WHERE_LONG = {"$and": [{"source": "langchain"}, {"tokens": {"$gte": 2000}}]}
print("where =", WHERE_LONG)

# A filter shrinks the eligible pool before any ranking happens — count it:
eligible = len(collection.get(where=WHERE_LONG)["ids"])
print(f"eligible chunks: {eligible} of {collection.count()}\n")

show_chunks(search("How does an agent decide which tool to call?", top_k=3, where=WHERE_LONG))
# Out:
# where = {'$and': [{'source': 'langchain'}, {'tokens': {'$gte': 2000}}]}
# eligible chunks: 1557 of 7428
#   0.7537 | langchain    | Agents                               |  schema: z.object({       query: z.string().describe("The query to search for"),     }),  …
#   0.7475 | langchain    | Models                               | agent](/oss/langchain/agents), the agent loop will handle the tool execution loop for you.…
#   0.7472 | langchain    | Agents                               |         # Use an advanced model for longer conversations         model = advanced_model   …

# %% [markdown]
# ## 8. Filtered vs Unfiltered, Side by Side — and Breaking Retrieval on Purpose
#
# The most instructive filter is one that *excludes the right answer*. In this corpus, everything about the `CLAUDE.md` memory file lives in a single source — the Claude Code docs; the other six sources never define it. So a `CLAUDE.md` question with `claude_code_docs` excluded — `{"source": {"$ne": "claude_code_docs"}}` — is a question whose gold documents are ineligible by construction. (If your corpus version differs, pick any question the unfiltered block answers from one source and exclude *that* source.) One query, three views: unfiltered, a filter that keeps the gold source, and a filter that excludes it. Watch the third block closely — it still returns chunks, and that is the point.

# %%
QUESTION = "What is the CLAUDE.md file and what belongs in it?"

VIEWS = [
    ("unfiltered",           None),
    ("gold source kept",     {"source": "claude_code_docs"}),
    ("gold source EXCLUDED", {"source": {"$ne": "claude_code_docs"}}),
]

for label, where in VIEWS:
    print(f"— {label:<22} | where={where}")
    show_chunks(search(QUESTION, top_k=3, where=where))
    print()
# Out:
# — unfiltered             | where=None
#   0.8315 | claude_code_docs | Best practices for Claude Code       |  This gives Claude persistent context it can't infer from code alone.  The `/init` command…
#   0.8171 | claude_code_docs | How Claude remembers your project    |  `./CLAUDE.md` or `./.claude/CLAUDE.md`. Create this file and add instructions that apply …
#   0.8021 | claude_code_docs | How Claude remembers your project    |  files still load and enter the context window at launch.  **Structure**: use markdown hea…
#
# — gold source kept       | where={'source': 'claude_code_docs'}
#   0.8315 | claude_code_docs | Best practices for Claude Code       |  This gives Claude persistent context it can't infer from code alone.  The `/init` command…
#   0.8171 | claude_code_docs | How Claude remembers your project    |  `./CLAUDE.md` or `./.claude/CLAUDE.md`. Create this file and add instructions that apply …
# ...

# %%
# End to end with the bad filter: same question, grounded generation.
reply, retrieved = answer(QUESTION, where={"source": {"$ne": "claude_code_docs"}})
print("Sources the model saw:", sorted({r["source"] for r in retrieved}))
print()
print(reply)
# Out:
# Sources the model saw: ['deep_agents', 'langchain', 'openai_docs']
#
# Based on the provided context, there is no mention or information regarding a `CLAUDE.md` file (the context only discusses `AGENTS.md` files and various Claude tools). Therefore, I cannot answer what a `CLAUDE.md` file is or what belongs in it based on the available text.

# %% [markdown]
# **What just happened?** The excluded-gold block did not come back empty — it returned the nearest *eligible* chunks, complete with plausible-looking scores, and the grounded answer degraded to some flavor of "the provided context doesn't cover this" (**your output will differ**). That is the failure mode to internalize: a `where` filter is a hard constraint, and vector search **always returns the nearest thing it is permitted to return** — it has no way to signal "everything relevant was filtered out." Two habits follow. When a RAG system suddenly can't answer questions it used to handle, check the active filter before blaming the model — in the production tutor, an over-narrow source selection produces exactly this behavior. And when scores for a familiar query sag across the board, diff against an unfiltered run: the gap between the first and third blocks above *is* the diagnostic.

# %% [markdown]
# ## 🔑 Key Takeaways
#
# - A `where` filter is a **hard constraint applied before similarity ranking**: it decides which chunks may compete, then scoring proceeds untouched. Filtering inside the query beats retrieve-then-prune, which silently spends your `top_k` budget on chunks you'll throw away.
# - The production shapes are two dicts: `{"source": {"$eq": ...}}` for one selected source, `{"source": {"$in": [...]}}` for several, `None` for no selection — `build_where_filter()` is the whole bridge from the tutor's source-picker UI to Chroma.
# - The operator toolbox composes: `$eq`/`$ne`, numeric comparisons (`$gt`, `$gte`, `$lt`, `$lte`), membership (`$in`/`$nin`), and `$and`/`$or` — and metadata you attach at ingest time (like `source` and `tokens`) is the only metadata you can filter on later.
# - Filters are product features, not optimizations: source scoping, per-user permissions, and freshness windows are all the same one-argument mechanism.
# - The failure mode is silent: exclude the gold documents and search still returns confident-looking neighbors. When retrieval goes strange, **check the filter first** — and diff against an unfiltered run.
#
# ⏭️ *Next: hybrid search. Filters constrain the candidate pool — who is allowed to compete. Hybrid search changes how the candidates are **scored** — dense vectors and keyword matching voting together on the same pool.*
