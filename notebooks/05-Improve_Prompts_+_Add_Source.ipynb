# %% [markdown]
# <a href="https://colab.research.google.com/github/towardsai/ai-tutor-rag-system/blob/main/notebooks/05-Improve_Prompts_+_Add_Source.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Improving Data Sources and Prompts: Ingestion, Metadata, and Cited Answers
#
# Two upgrades separate a demo RAG system from one people trust: **ingestion that preserves where every chunk came from**, and **answers that cite their sources**. In this notebook we wrap our chunk → embed → store flow into one `ingest()` function that carries title/URL/source metadata into the database, and we make the prompt *visible* — an explicit f-string with rules, numbered sources, and the question — so the model can ground every claim in a citation.
#
# 📎 *Same pipeline, same Chroma collection pattern as the previous notebook. The production AI Tutor resolves citations exactly this way: chunk metadata in, `[n]` references out.*

# %% [markdown]
# ## 🧭 What You'll Learn
#
# - `ingest()`: chunking, embedding, and upserting as **one idempotent function**
# - Why metadata (title, URL, source) must enter the database *with* the chunks — not be bolted on later
# - The **explicit prompt template**: rules, numbered sources, question — no framework hiding your prompt
# - **Citation grounding**: the model cites `[1]`, `[2]`… and you resolve them back to titles and URLs
# - Debugging retrieval separately from generation (look at chunks and scores *before* paying for an answer)

# %% [markdown]
# ## 1. Setup: Environment, Keys, and Providers
#
# The standard course setup cell with this lesson's pinned extras (`chromadb`, `tiktoken`).
#
# The **model fields are editable dropdowns** (`{allow-input: true}`): pick a listed course default or type any newer model ID — no code changes needed. (Locally, simply edit the string.)

# %%
# ============================================================
# ⚙️ Setup — environment, dependencies, API keys, provider
# ============================================================
import os
import sys

IN_COLAB = "google.colab" in sys.modules

# Pick your model providers (dropdowns in Colab; edit the values locally)
PROVIDER = "gemini"  # @param ["gemini", "openai", "anthropic"]
EMBED_PROVIDER = "gemini"  # @param ["gemini", "openai"]  (Anthropic has no embedding API)

# Pick a model for the selected provider — or TYPE any newer model ID into the
# box (the dropdown is editable thanks to allow-input):
CHAT_MODEL = "gemini-3.7-flash"  # @param ["gemini-3.7-flash", "gemini-3.5-flash-lite", "gpt-5.6-luna", "claude-sonnet-5"] {allow-input: true}
EMBED_MODEL = "gemini-embedding-001"  # @param ["gemini-embedding-001", "text-embedding-3-small"] {allow-input: true}

_KEY_FOR = {"gemini": "GOOGLE_API_KEY", "openai": "OPENAI_API_KEY", "anthropic": "ANTHROPIC_API_KEY"}
REQUIRED_KEYS = sorted({_KEY_FOR[PROVIDER], _KEY_FOR[EMBED_PROVIDER]})

if IN_COLAB:
    import importlib
    import site
    import subprocess

    # Shared install profile, pinned course-wide (July 2026).
    subprocess.run(
        [
            sys.executable, "-m", "pip", "install", "-q", "-U",
            "google-genai==2.3.0",
            "openai==2.46.0",
            "anthropic==0.117.0",
            "chromadb==1.5.9",
            "tiktoken==0.13.0",
        ],
        check=True,
    )
    importlib.reload(site)  # make newly installed packages importable without a runtime restart

    # In Colab: Secrets tab (🔑 icon) → Add new secret → e.g. GOOGLE_API_KEY
    from google.colab import userdata

    for key in REQUIRED_KEYS:
        os.environ[key] = userdata.get(key)

if not IN_COLAB:
    get_ipython().run_line_magic("load_ext", "autoreload")
    get_ipython().run_line_magic("autoreload", "2")

    # Locally: dependencies are installed once from the repo's requirements.
    # Keys live in a .env file at the repo root.
    from dotenv import load_dotenv

    load_dotenv()
    missing = [k for k in REQUIRED_KEYS if not os.getenv(k)]
    assert not missing, f"Missing from .env: {missing}"

print(f"✅ Setup complete — {'Colab' if IN_COLAB else 'local'} | chat: {PROVIDER} | embeddings: {EMBED_PROVIDER}")
# Out:
# ✅ Setup complete — local | chat: gemini | embeddings: gemini

# %% [markdown]
# ## 2. `generate()` and `embed()`
#
# 📎 *Unchanged — the course's two provider helpers.*

# %%
# 📎 generate() was built in the "How To Use LLMs via API" notebook.
#    embed() is NEW in this notebook — and reused for the rest of the course.
from anthropic import Anthropic
from google import genai
from google.genai import types as genai_types
from openai import OpenAI

# Course-standard default models per provider (August 2026)
MODELS = {
    "gemini": "gemini-3.7-flash",
    "openai": "gpt-5.6-luna",
    "anthropic": "claude-sonnet-5",
}

# The setup-cell form selection (or any typed model ID) overrides the default:
MODELS[PROVIDER] = CHAT_MODEL
EMBED_MODELS = {
    "gemini": "gemini-embedding-001",
    "openai": "text-embedding-3-small",
}
EMBED_MODELS[EMBED_PROVIDER] = EMBED_MODEL  # setup-cell selection (or typed ID) wins
EMBED_DIM = 1536  # same output size for both providers, so the rest of the code never cares

# Create only the clients we actually need
if "gemini" in (PROVIDER, EMBED_PROVIDER):
    gemini_client = genai.Client()
if "openai" in (PROVIDER, EMBED_PROVIDER):
    openai_client = OpenAI()
if PROVIDER == "anthropic":
    anthropic_client = Anthropic()


def generate(prompt, system=None, model=None):
    """Send one prompt to the selected PROVIDER and return the reply text."""
    if PROVIDER == "gemini":
        response = gemini_client.models.generate_content(
            model=model or MODELS["gemini"],
            contents=prompt,
            config=genai_types.GenerateContentConfig(system_instruction=system),
        )
        return response.text

    if PROVIDER == "openai":
        response = openai_client.responses.create(
            model=model or MODELS["openai"],
            instructions=system,
            input=prompt,
            reasoning={"effort": "none"},
        )
        return response.output_text

    if PROVIDER == "anthropic":
        response = anthropic_client.messages.create(
            model=model or MODELS["anthropic"],
            max_tokens=4096,
            **({"system": system} if system else {}),
            messages=[{"role": "user", "content": prompt}],
        )
        return response.content[0].text

    raise ValueError(f"Unknown PROVIDER: {PROVIDER!r}")


def embed(texts, task="document"):
    """Embed a list of texts with the selected EMBED_PROVIDER.

    Returns a list of EMBED_DIM-dimensional vectors (one per input text).
    task: "document" for corpus chunks, "query" for user questions —
    Gemini embeds the two slightly differently to improve retrieval.
    """
    if isinstance(texts, str):
        texts = [texts]
    # Embedding models work best on single-line inputs
    texts = [t.replace("\n", " ") for t in texts]

    if EMBED_PROVIDER == "gemini":
        result = gemini_client.models.embed_content(
            model=EMBED_MODELS["gemini"],
            contents=texts,
            config=genai_types.EmbedContentConfig(
                task_type="RETRIEVAL_DOCUMENT" if task == "document" else "RETRIEVAL_QUERY",
                output_dimensionality=EMBED_DIM,
            ),
        )
        return [e.values for e in result.embeddings]

    if EMBED_PROVIDER == "openai":
        result = openai_client.embeddings.create(
            model=EMBED_MODELS["openai"], input=texts
        )
        return [d.embedding for d in result.data]

    raise ValueError(f"Unknown EMBED_PROVIDER: {EMBED_PROVIDER!r}")

# %% [markdown]
# ## 3. Load the Articles (with Their Metadata)
#
# Each article keeps its **title, URL, and source name**. This is the "improving data sources" half of the lesson: a knowledge base without provenance cannot cite, cannot filter, and cannot be audited.

# %%
import csv
import pathlib

import requests

# Course dataset — hosted in the Towards AI org dataset repo on Hugging Face
DATA_URL = "https://huggingface.co/datasets/towardsai-tutors/full-stack-ai-engineering-data/resolve/main/ai-docs.csv"
DATA_PATH = pathlib.Path("ai-docs.csv")

if not DATA_PATH.exists():
    DATA_PATH.write_bytes(requests.get(DATA_URL, timeout=30).content)
    print("Downloaded", DATA_PATH)

# Read the articles WITH their metadata (title, url, source) — we carry it everywhere
articles = []
with open(DATA_PATH, mode="r", encoding="utf-8") as f:
    for idx, row in enumerate(csv.reader(f)):
        if idx == 0:
            continue  # skip the header row
        articles.append({"title": row[0], "text": row[1], "url": row[2], "source": row[3]})

print(f"{len(articles)} articles loaded")
# Out:
# 23 articles loaded

# %%
import tiktoken

# The tokenizer used for counting: chunk sizes in this course are measured in TOKENS
ENC = tiktoken.get_encoding("cl100k_base")


def n_tokens(text):
    """Number of tokens in a string."""
    return len(ENC.encode(text))


def chunk(text, chunk_size=512, chunk_overlap=128):
    """Split text into token-based chunks; consecutive chunks share chunk_overlap tokens."""
    tokens = ENC.encode(text)
    chunks = []
    step = chunk_size - chunk_overlap
    for start in range(0, len(tokens), step):
        window = tokens[start : start + chunk_size]
        chunks.append(ENC.decode(window))
        if start + chunk_size >= len(tokens):
            break  # the final window reached the end of the text
    return chunks

# %% [markdown]
# ## 4. `ingest()`: Chunk → Embed → Upsert, as One Function
#
# Previously we chunked, embedded, and upserted in three loose cells. Production systems run ingestion many times — new articles, edited pages, re-chunks — so it deserves a single **idempotent** function: stable chunk ids mean re-ingesting the same article updates it instead of duplicating it.

# %%
import chromadb

chroma_client = chromadb.PersistentClient(path="./ai-docs-chroma")
collection = chroma_client.get_or_create_collection(
    name="ai-docs",
    metadata={"hnsw:space": "cosine"},  # distance = 1 - cosine similarity
)


def ingest(articles, collection, chunk_size=512, chunk_overlap=128, batch_size=50):
    """Chunk each article, embed the chunks, and upsert them with metadata.

    Idempotent: stable ids mean re-running updates rather than duplicates.
    """
    records = []
    for art in articles:
        for i, piece in enumerate(chunk(art["text"], chunk_size, chunk_overlap)):
            records.append({
                "id": f"{art['title'][:40]}-{i}",
                "text": piece,
                "title": art["title"],
                "url": art["url"],
                "source": art["source"],
            })

    for start in range(0, len(records), batch_size):
        batch = records[start : start + batch_size]
        collection.upsert(
            ids=[r["id"] for r in batch],
            documents=[r["text"] for r in batch],
            embeddings=embed([r["text"] for r in batch], task="document"),
            metadatas=[{"title": r["title"], "url": r["url"], "source": r["source"]} for r in batch],
        )
    return len(records)


n = ingest(articles, collection)
print(f"Ingested {n} chunks | collection now holds {collection.count()} items")
# Out:
# Ingested 233 chunks | collection now holds 233 items

# %% [markdown]
# **What just happened?** One call took raw articles to a queryable, metadata-rich knowledge base — and running it again changes nothing (same ids, same content). This function *is* the ingestion pipeline: when the corpus later grows to scraped webpages and parsed PDFs, they all enter through `ingest()`.

# %% [markdown]
# ## 5. `search()` — Chroma-Backed, Metadata Out
#
# 📎 *Same function as the previous notebook: top-k chunks with scores and metadata.*

# %%
def search(query, top_k=5, where=None):
    """Return the top_k most relevant chunks: text, score, metadata."""
    result = collection.query(
        query_embeddings=[embed(query, task="query")[0]],
        n_results=top_k,
        where=where,
    )
    return [
        {"text": doc, "score": 1 - dist, **meta}
        for doc, dist, meta in zip(
            result["documents"][0], result["distances"][0], result["metadatas"][0]
        )
    ]


# Debug retrieval BEFORE generation: chunks, scores, titles — no LLM cost yet.
for r in search("How many parameters does the Qwen3.8 model have?", top_k=3):
    print(f"┌─ {r['score']:.4f} | {r['title'][:60]}")
    print(f"│  {r['text'][:180]}".replace("\n", " "))
    print("└" + "─" * 60)
# Out:
# ┌─ 0.7828 | Qwen3.8-2.4T-A95B Model Card
# │  # Qwen3.8-2.4T-A95B  ## Qwen3.8 Highlights  Qwen3.8 features the following enhancements:  - Core Capabilities: Comprehensive improvements across coding, professional work, research
# └────────────────────────────────────────────────────────────
# ┌─ 0.7407 | Qwen3.8-2.4T-A95B Model Card
# │  144 natively and extensible up to 1,010,000 tokens.  ## Benchmark Results  | | Opus 4.8 | Fable 5 | GPT 5.6 Sol (max) | Qwen3.7-Max | Qwen3.8-Max |  | Coding Agent | | | | | | | Te
# └────────────────────────────────────────────────────────────
# ┌─ 0.7299 | Qwen3.8-2.4T-A95B Model Card
# │   Usage  Qwen3.8 comes with official support for `reasoning_effort`, which can be used to adjust reasoning depth and control cost:  - `xhigh` (default): for complex tasks demanding
# └────────────────────────────────────────────────────────────

# %% [markdown]
# **What just happened?** We inspected retrieval on its own — chunks, scores, titles — without paying for generation. This "retrieval-only" pass is the first thing to check whenever answers look wrong: if the right chunk is not in this list, no prompt template can save the answer.

# %% [markdown]
# ## 6. The Explicit Prompt Template: Rules, Numbered Sources, Question
#
# Here is the whole trick of "response synthesis", laid out in one visible f-string. Three parts, in priority order: **rules** (answer only from sources, cite as `[n]`, refuse if unsupported), **numbered sources** (each chunk labeled with its number, title, and URL — straight from the metadata we ingested), and the **question**. Nothing hidden, nothing to reverse-engineer: when an answer misbehaves, you read the exact prompt that produced it.

# %%
CITED_PROMPT = """You are an AI tutor answering strictly from the numbered sources below.

Rules:
- Use ONLY the sources between <SOURCES> and </SOURCES> to answer.
- Cite the sources you use inline as [1], [2], ... after each claim.
- If the sources do not contain the answer, reply that you cannot answer from the provided sources.

<SOURCES>
{sources}
</SOURCES>

Question: {question}
Answer (with [n] citations):"""


def answer_with_sources(question, top_k=5):
    """Grounded answer with inline [n] citations resolved from chunk metadata."""
    retrieved = search(question, top_k=top_k)
    sources_block = "\n\n".join(
        f"[{i + 1}] {r['title']} ({r['url']})\n{r['text']}"
        for i, r in enumerate(retrieved)
    )
    reply = generate(CITED_PROMPT.format(sources=sources_block, question=question))
    return reply, retrieved

# %%
reply, retrieved = answer_with_sources("How many parameters does the Qwen3.8 model have?")

print(reply)
print("\nSources cited above resolve to:")
for i, r in enumerate(retrieved, start=1):
    print(f"  [{i}] {r['title'][:70]}  —  {r['url']}")
# Out:
# Based on the provided sources, the Qwen3.8 model has **2.4T parameters in total**, with **95B activated** [1].
#
# Sources cited above resolve to:
#   [1] Qwen3.8-2.4T-A95B Model Card  —  https://huggingface.co/Qwen/Qwen3.8-2.4T-A95B
#   [2] Qwen3.8-2.4T-A95B Model Card  —  https://huggingface.co/Qwen/Qwen3.8-2.4T-A95B
#   [3] Qwen3.8-2.4T-A95B Model Card  —  https://huggingface.co/Qwen/Qwen3.8-2.4T-A95B
#   [4] Qwen3.8-2.4T-A95B Model Card  —  https://huggingface.co/Qwen/Qwen3.8-2.4T-A95B
#   [5] Kimi K3 Model Card  —  https://huggingface.co/moonshotai/Kimi-K3

# %% [markdown]
# **What just happened?** The model answered *and told us which sources back each claim* — and because every `[n]` maps to a chunk whose title and URL we stored at ingestion, the citations are resolvable links, not decoration. This is **citation grounding**, and it is precisely how the production AI Tutor renders its "sources" panel: chunk metadata in, `[n]` references out, URLs back to the user.

# %%
# The refusal path: a question our sources cannot answer should produce
# an honest "cannot answer from the provided sources" — with no fake citations.
# (Llama 2 is nowhere in the ai-docs corpus, so this MUST refuse. If it answers
# anyway, the model is leaking training memory past your rules — a red flag.)
reply, _ = answer_with_sources("How many parameters does the Llama 2 model have?")
print(reply)
# Out:
# I cannot answer this question from the provided sources, as they do not contain information about the Llama 2 model.

# %% [markdown]
# ## 7. One Visible Template Instead of "Response Modes"
#
# Frameworks ship preset "response modes" — *compact* (stuff all chunks into one prompt), *refine* (answer from the first chunk, then revise it chunk by chunk, one LLM call each), *tree-summarize* (recursively summarize until one answer remains). Our template **is** the compact strategy, and now you can see why it is the default: one call, full context, lowest cost. The other two are just loops you could write around `generate()` in five lines each — worth it only for corpora too big to stuff, at multiple-calls-per-answer prices. When you control the template, response strategies are a design choice, not a config flag.
#
# 💡 *Debugging tip carried from the old version of this lesson: retrieval-without-generation (just call `search()`) replaces the framework's `no_text` mode — same insight, zero magic.*

# %% [markdown]
# ## 🔑 Key Takeaways
#
# - Ingestion is a **function, not a ritual**: `ingest()` = chunk → embed → upsert with stable ids, safe to re-run forever.
# - Metadata is not optional garnish — title, URL, and source enter the database *with* each chunk, or citations and filtering are impossible later.
# - The prompt template is **yours and visible**: rules, numbered sources, question. When answers misbehave, you read the exact prompt — no framework archaeology.
# - **Citation grounding** = numbered sources in, `[n]` references out, resolved back to titles and URLs from chunk metadata — the production tutor's exact pattern.
# - Debug retrieval and generation *separately*: `search()` first (free of LLM cost), template second.
# - "Response modes" demystified: compact is one stuffed prompt (our default); refine and tree-summarize are multi-call loops you can write yourself when the corpus demands it.
